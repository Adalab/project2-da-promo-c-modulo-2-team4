# %%
import pandas as pd
import re
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidetable

# %%
pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %% [markdown]
# Cargamos el archivo limpio

# %%
# Abrir con index_col = 0
df = pd.read_csv("../data/6.dataframe_analisis.csv", index_col = 0)

# Se hace esto para resetear los índices
df.reset_index(drop=True , inplace=True)
df.head(2)
# Out:
#   q1_edad q2_genero    q3_país       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech q8_l_recomendado  \
# 0  5-10 years           Python
# 1   20+ years           Python
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# 0      $100-$999                 NaN              NaN
# 1      $0 ($USD)                 NaN              NaN
#
#                                   q41_h_process_data     q7_l_utilizados  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                            q14_h_viz         q10_part_1  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                        Matplotlib    Kaggle Notebooks
#
#         q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# 0  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#   q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
#
#   q10_part_14 q10_part_15 q10_part_16 q10_other  \
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
#
#                                           q18_part_1 q18_part_2 q18_part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1 q27_a_part_2  \
# 0        NaN        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN        NaN       NaN          NaN          NaN
#
#                     q27_a_part_3 q27_a_part_4 q27_a_part_5 q27_a_part_6  \
# 0   Google Cloud Platform (GCP)           NaN          NaN          NaN
# 1                            NaN          NaN          NaN          NaN
#
#   q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10 q27_a_part_11  \
# 0          NaN          NaN          NaN           NaN           NaN
# 1          NaN          NaN          NaN           NaN           NaN
#
#   q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4 q39_part_5  \
# 0         NaN        NaN        NaN        NaN    GitHub         NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
#
#   q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other q40_part_1 q40_part_2  \
# 0    Kaggle         NaN        NaN        NaN       NaN   Coursera        edX
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
#
#              q40_part_3 q40_part_4 q40_part_5 q40_part_6 q40_part_7  \
# 0  Kaggle Learn Courses   DataCamp        NaN    Udacity      Udemy
# 1  Kaggle Learn Courses        NaN        NaN        NaN        NaN
#
#   q40_part_8                                         q40_part_9  \
# 0        NaN                                                NaN
# 1        NaN  Cloud-certification programs (direct from AWS,...
#
#                                          q40_part_10 q40_part_11 q40_other  \
# 0                                                NaN         NaN       NaN
# 1  University Courses (resulting in a university ...         NaN       NaN
#
#   q42_part_1                                         q42_part_2 q42_part_3  \
# 0        NaN  Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 1        NaN                                                NaN        NaN
#
#                         q42_part_4 q42_part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
#
#                                           q42_part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
#
#                                           q42_part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
#
#                                           q42_part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
#
#                                           q42_part_9 q42_part_10 q42_part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   q42_other
# 0       NaN
# 1       NaN

# %% [markdown]
# df.columns

# %% [markdown]
# # Valores duplicados

# %%
df.duplicated().sum()
# Out:
# 8

# %% [markdown]
# # Eliminar los duplicados

# %%
df.drop_duplicates(inplace= True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Cambios en tipos de columnas (astype)

# %%
# df.select_dtypes(include=np.number)
# No tenemos variables numéricas

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['q1_edad', 'q2_genero', 'q3_país', 'q4_educacion', 'q5_ocupacion',
#        'q6_exp_tech', 'q8_l_recomendado', 'q11_tipo_plataforma',
#        'q20_i_actual', 'q21_tamanio_cia', 'q22_da_cia', 'q25_salario',
#        'q26_ppto_ml_cc', 'q33_bigdata_product', 'q35_h_i_negocios',
#        'q41_h_process_data', 'q7_l_utilizados', 'q9_adi', 'q14_h_viz',
#        'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
#        'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
#        'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
#        'q10_part_15', 'q10_part_16', 'q10_other', 'q18_part_1', 'q18_part_2',
#        'q18_part_3', 'q18_part_4', 'q18_part_5', 'q18_part_6', 'q18_other',
#        'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
#        'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
#        'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',
#        'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
#        'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other',
#        'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
#        'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
#        'q40_part_11', 'q40_other', 'q42_part_1', 'q42_part_2', 'q42_part_3',
#        'q42_part_4', 'q42_part_5', 'q42_part_6', 'q42_part_7', 'q42_part_8',
#        'q42_part_9', 'q42_part_10', 'q42_part_11', 'q42_other'],
#       dtype='object')

# %%
df.shape
# Out:
# (25965, 89)

# %% [markdown]
# # Ordenar columnas. `Pendiente`

# %%
df.head(2)
# Out:
#   q1_edad q2_genero    q3_país       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech q8_l_recomendado  \
# 0  5-10 years           Python
# 1   20+ years           Python
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# 0      $100-$999                 NaN              NaN
# 1      $0 ($USD)                 NaN              NaN
#
#                                   q41_h_process_data     q7_l_utilizados  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                            q14_h_viz         q10_part_1  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                        Matplotlib    Kaggle Notebooks
#
#         q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# 0  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#   q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
#
#   q10_part_14 q10_part_15 q10_part_16 q10_other  \
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
#
#                                           q18_part_1 q18_part_2 q18_part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1 q27_a_part_2  \
# 0        NaN        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN        NaN       NaN          NaN          NaN
#
#                     q27_a_part_3 q27_a_part_4 q27_a_part_5 q27_a_part_6  \
# 0   Google Cloud Platform (GCP)           NaN          NaN          NaN
# 1                            NaN          NaN          NaN          NaN
#
#   q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10 q27_a_part_11  \
# 0          NaN          NaN          NaN           NaN           NaN
# 1          NaN          NaN          NaN           NaN           NaN
#
#   q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4 q39_part_5  \
# 0         NaN        NaN        NaN        NaN    GitHub         NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
#
#   q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other q40_part_1 q40_part_2  \
# 0    Kaggle         NaN        NaN        NaN       NaN   Coursera        edX
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
#
#              q40_part_3 q40_part_4 q40_part_5 q40_part_6 q40_part_7  \
# 0  Kaggle Learn Courses   DataCamp        NaN    Udacity      Udemy
# 1  Kaggle Learn Courses        NaN        NaN        NaN        NaN
#
#   q40_part_8                                         q40_part_9  \
# 0        NaN                                                NaN
# 1        NaN  Cloud-certification programs (direct from AWS,...
#
#                                          q40_part_10 q40_part_11 q40_other  \
# 0                                                NaN         NaN       NaN
# 1  University Courses (resulting in a university ...         NaN       NaN
#
#   q42_part_1                                         q42_part_2 q42_part_3  \
# 0        NaN  Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 1        NaN                                                NaN        NaN
#
#                         q42_part_4 q42_part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
#
#                                           q42_part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
#
#                                           q42_part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
#
#                                           q42_part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
#
#                                           q42_part_9 q42_part_10 q42_part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   q42_other
# 0       NaN
# 1       NaN

# %% [markdown]
# # Tratamiento de los outliers

# %% [markdown]
# No existen outliers

# %%
df_numericas = df.select_dtypes(include=np.number)

# %% [markdown]
# # Tratamiento de nulos

# %%
df.stb.missing()
# Out:
#                      missing  total    percent
# q18_other              25846  25965  99.541691
# q39_part_3             25829  25965  99.476218
# q10_part_15            25818  25965  99.433853
# q14_h_viz               2001  25965   7.706528
# q11_tipo_plataforma     1251  25965   4.818024
# q9_adi                  1038  25965   3.997689
# q8_l_recomendado        1032  25965   3.974581
# q7_l_utilizados         1031  25965   3.970730
# q6_exp_tech                0  25965   0.000000
# q5_ocupacion               0  25965   0.000000
# q2_genero                  0  25965   0.000000
# q4_educacion               0  25965   0.000000
# q3_país                    0  25965   0.000000
# q1_edad                    0  25965   0.000000

# %% [markdown]
# De la q1 a q6 no existen valores nulos

# %%
lista_q_18 = ['q18_part_1', 'q18_part_2', 'q18_part_3', 'q18_part_4', 'q18_part_5',
       'q18_part_6', 'q18_other']

# %%
df_q18 = df[lista_q_18]
df_q18.head(10)
# Out:
#                                           q18_part_1  \
# 0  General purpose image/video tools (PIL, cv2, s...
# 1                                                NaN
# 2                                                NaN
# 3  General purpose image/video tools (PIL, cv2, s...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                           q18_part_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Image segmentation methods (U-Net, Mask R-CNN,...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Image segmentation methods (U-Net, Mask R-CNN,...
# 8                                                NaN
# 9                                                NaN
#
#                                           q18_part_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Object detection methods (YOLOv3, RetinaNet, etc)
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Object detection methods (YOLOv3, RetinaNet, etc)
# 8                                                NaN
# 9                                                NaN
#
#                                           q18_part_4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Image classification and other general purpose...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Image classification and other general purpose...
# 8                                                NaN
# 9                                                NaN
#
#                             q18_part_5 q18_part_6 q18_other
# 0                                  NaN        NaN       NaN
# 1                                  NaN        NaN       NaN
# 2                                  NaN        NaN       NaN
# 3                                  NaN        NaN       NaN
# 4                                  NaN        NaN       NaN
# 5                                  NaN        NaN       NaN
# 6                                  NaN        NaN       NaN
# 7  Generative Networks (GAN, VAE, etc)        NaN       NaN
# 8                                  NaN        NaN       NaN
# 9                                  NaN        NaN       NaN

# %%
df_q18.shape
# Out:
# (25965, 7)

# %%
# df_18_sin_nulos = df_q18.dropna(how=all )

# %%
df_q18.stb.missing()
# Out:
#             missing  total    percent
# q18_other     25846  25965  99.541691
# q18_part_6    24526  25965  94.457924
# q18_part_5    24473  25965  94.253803
# q18_part_1    23303  25965  89.747737
# q18_part_3    23249  25965  89.539765
# q18_part_2    23225  25965  89.447333
# q18_part_4    21592  25965  83.158097

# %%
df["q5_ocupacion"].value_counts()
# Out:
# Student                         6798
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2392
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1498
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: q5_ocupacion, dtype: int64

# %% [markdown]
# DF para responder a preguntas 3, sobre herramientas

# %%
df_analistas = df[df["q5_ocupacion"]== "Data Analyst"]

# %%
df_analistas.stb.missing()
# Out:
#                      missing  total    percent
# q18_other               2291   2301  99.565406
# q10_part_4              2287   2301  99.391569
# q22_da_cia               150   2301   6.518905
# q9_adi                   146   2301   6.345067
# q8_l_recomendado         144   2301   6.258149
# q7_l_utilizados          143   2301   6.214689
# q21_tamanio_cia          130   2301   5.649718
# q20_i_actual             114   2301   4.954368
# q2_genero                  0   2301   0.000000
# q6_exp_tech                0   2301   0.000000
# q5_ocupacion               0   2301   0.000000
# q4_educacion               0   2301   0.000000
# q3_país                    0   2301   0.000000
# q1_edad                    0   2301   0.000000

# %%
df_analistas.shape
# Out:
# (2301, 89)

# %%
lista_eliminar = ['q18_part_1', 'q18_part_2', 'q18_part_3', 'q18_part_4', 'q18_part_5',
       'q18_part_6', 'q18_other',
       
       'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
       'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
       'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
       'q10_part_15', 'q10_part_16', 'q10_other', 
       
       'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
       'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other', 
       
       'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
       'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
       'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',


       'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
       'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
       'q40_part_11', 'q40_other']

# %%
df_analistas = df_analistas.drop(['q18_part_1', 'q18_part_2', 'q18_part_3', 'q18_part_4', 'q18_part_5',
       'q18_part_6', 'q18_other',
       
       'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
       'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
       'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
       'q10_part_15', 'q10_part_16', 'q10_other', 
       
       'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
       'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other', 
       
       'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
       'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
       'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',


       'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
       'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
       'q40_part_11', 'q40_other'], axis=1)

# %%
df_analistas.shape
# Out:
# (2301, 31)
