# %%
import pandas as pd
import re
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidetable

# %%
pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %% [markdown]
# Cargamos el archivo limpio

# %%
# Abrir con index_col = 0
df = pd.read_csv("../data/6.dataframe_analisis.csv", index_col = 0)

# Se hace esto para resetear los índices
df.reset_index(drop=True , inplace=True)
df.head(2)
# Out:
#   q1_edad q2_genero    q3_país       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech q8_l_recomendado  \
# 0  5-10 years           Python
# 1   20+ years           Python
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# 0      $100-$999                 NaN              NaN
# 1      $0 ($USD)                 NaN              NaN
#
#                                   q41_h_process_data     q7_l_utilizados  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                            q14_h_viz         q10_part_1  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                        Matplotlib    Kaggle Notebooks
#
#         q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# 0  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#   q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
#
#   q10_part_14 q10_part_15 q10_part_16 q10_other  \
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
#
#                                           q18_part_1 q18_part_2 q18_part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1 q27_a_part_2  \
# 0        NaN        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN        NaN       NaN          NaN          NaN
#
#                     q27_a_part_3 q27_a_part_4 q27_a_part_5 q27_a_part_6  \
# 0   Google Cloud Platform (GCP)           NaN          NaN          NaN
# 1                            NaN          NaN          NaN          NaN
#
#   q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10 q27_a_part_11  \
# 0          NaN          NaN          NaN           NaN           NaN
# 1          NaN          NaN          NaN           NaN           NaN
#
#   q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4 q39_part_5  \
# 0         NaN        NaN        NaN        NaN    GitHub         NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
#
#   q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other q40_part_1 q40_part_2  \
# 0    Kaggle         NaN        NaN        NaN       NaN   Coursera        edX
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
#
#              q40_part_3 q40_part_4 q40_part_5 q40_part_6 q40_part_7  \
# 0  Kaggle Learn Courses   DataCamp        NaN    Udacity      Udemy
# 1  Kaggle Learn Courses        NaN        NaN        NaN        NaN
#
#   q40_part_8                                         q40_part_9  \
# 0        NaN                                                NaN
# 1        NaN  Cloud-certification programs (direct from AWS,...
#
#                                          q40_part_10 q40_part_11 q40_other  \
# 0                                                NaN         NaN       NaN
# 1  University Courses (resulting in a university ...         NaN       NaN
#
#   q42_part_1                                         q42_part_2 q42_part_3  \
# 0        NaN  Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 1        NaN                                                NaN        NaN
#
#                         q42_part_4 q42_part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
#
#                                           q42_part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
#
#                                           q42_part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
#
#                                           q42_part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
#
#                                           q42_part_9 q42_part_10 q42_part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   q42_other
# 0       NaN
# 1       NaN

# %% [markdown]
# df.columns

# %% [markdown]
# # Valores duplicados

# %%
df.duplicated().sum()
# Out:
# 8

# %% [markdown]
# # Eliminar los duplicados

# %%
df.drop_duplicates(inplace= True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Cambios en tipos de columnas (astype)

# %%
# df.select_dtypes(include=np.number)
# No tenemos variables numéricas

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['q1_edad', 'q2_genero', 'q3_país', 'q4_educacion', 'q5_ocupacion',
#        'q6_exp_tech', 'q8_l_recomendado', 'q11_tipo_plataforma',
#        'q20_i_actual', 'q21_tamanio_cia', 'q22_da_cia', 'q25_salario',
#        'q26_ppto_ml_cc', 'q33_bigdata_product', 'q35_h_i_negocios',
#        'q41_h_process_data', 'q7_l_utilizados', 'q9_adi', 'q14_h_viz',
#        'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
#        'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
#        'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
#        'q10_part_15', 'q10_part_16', 'q10_other', 'q18_part_1', 'q18_part_2',
#        'q18_part_3', 'q18_part_4', 'q18_part_5', 'q18_part_6', 'q18_other',
#        'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
#        'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
#        'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',
#        'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
#        'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other',
#        'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
#        'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
#        'q40_part_11', 'q40_other', 'q42_part_1', 'q42_part_2', 'q42_part_3',
#        'q42_part_4', 'q42_part_5', 'q42_part_6', 'q42_part_7', 'q42_part_8',
#        'q42_part_9', 'q42_part_10', 'q42_part_11', 'q42_other'],
#       dtype='object')

# %%
df.shape
# Out:
# (25965, 89)

# %% [markdown]
# # Ordenar columnas. `Pendiente`

# %%
df.head(2)
# Out:
#   q1_edad q2_genero    q3_país       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech q8_l_recomendado  \
# 0  5-10 years           Python
# 1   20+ years           Python
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# 0      $100-$999                 NaN              NaN
# 1      $0 ($USD)                 NaN              NaN
#
#                                   q41_h_process_data     q7_l_utilizados  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                            q14_h_viz         q10_part_1  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                        Matplotlib    Kaggle Notebooks
#
#         q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# 0  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#   q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
#
#   q10_part_14 q10_part_15 q10_part_16 q10_other  \
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
#
#                                           q18_part_1 q18_part_2 q18_part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1 q27_a_part_2  \
# 0        NaN        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN        NaN       NaN          NaN          NaN
#
#                     q27_a_part_3 q27_a_part_4 q27_a_part_5 q27_a_part_6  \
# 0   Google Cloud Platform (GCP)           NaN          NaN          NaN
# 1                            NaN          NaN          NaN          NaN
#
#   q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10 q27_a_part_11  \
# 0          NaN          NaN          NaN           NaN           NaN
# 1          NaN          NaN          NaN           NaN           NaN
#
#   q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4 q39_part_5  \
# 0         NaN        NaN        NaN        NaN    GitHub         NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
#
#   q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other q40_part_1 q40_part_2  \
# 0    Kaggle         NaN        NaN        NaN       NaN   Coursera        edX
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
#
#              q40_part_3 q40_part_4 q40_part_5 q40_part_6 q40_part_7  \
# 0  Kaggle Learn Courses   DataCamp        NaN    Udacity      Udemy
# 1  Kaggle Learn Courses        NaN        NaN        NaN        NaN
#
#   q40_part_8                                         q40_part_9  \
# 0        NaN                                                NaN
# 1        NaN  Cloud-certification programs (direct from AWS,...
#
#                                          q40_part_10 q40_part_11 q40_other  \
# 0                                                NaN         NaN       NaN
# 1  University Courses (resulting in a university ...         NaN       NaN
#
#   q42_part_1                                         q42_part_2 q42_part_3  \
# 0        NaN  Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 1        NaN                                                NaN        NaN
#
#                         q42_part_4 q42_part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
#
#                                           q42_part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
#
#                                           q42_part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
#
#                                           q42_part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
#
#                                           q42_part_9 q42_part_10 q42_part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   q42_other
# 0       NaN
# 1       NaN

# %% [markdown]
# # Tratamiento de los outliers

# %% [markdown]
# No existen outliers

# %%
df_numericas = df.select_dtypes(include=np.number)

# %% [markdown]
# # Tratamiento de nulos

# %%
df.stb.missing()
# Out:
#                missing  total    percent
# q18_other        25846  25965  99.541691
# q39_part_3       25829  25965  99.476218
# q10_part_15      25818  25965  99.433853
# q27_a_part_10    25793  25965  99.337570
# q10_part_6       25790  25965  99.326016
# ...                ...    ...        ...
# q5_ocupacion         0  25965   0.000000
# q2_genero            0  25965   0.000000
# q4_educacion         0  25965   0.000000
# q3_país              0  25965   0.000000
# q1_edad              0  25965   0.000000
#
# [89 rows x 3 columns]

# %% [markdown]
# De la q1 a q6 no existen valores nulos

# %%
lista_q_18 = ['q18_part_1', 'q18_part_2', 'q18_part_3', 'q18_part_4', 'q18_part_5',
       'q18_part_6', 'q18_other']

# %%
df_q18 = df[lista_q_18]
df_q18.head(10)
# Out:
#                                           q18_part_1  \
# 0  General purpose image/video tools (PIL, cv2, s...
# 1                                                NaN
# 2                                                NaN
# 3  General purpose image/video tools (PIL, cv2, s...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                           q18_part_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Image segmentation methods (U-Net, Mask R-CNN,...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Image segmentation methods (U-Net, Mask R-CNN,...
# 8                                                NaN
# 9                                                NaN
#
#                                           q18_part_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Object detection methods (YOLOv3, RetinaNet, etc)
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Object detection methods (YOLOv3, RetinaNet, etc)
# 8                                                NaN
# 9                                                NaN
#
#                                           q18_part_4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Image classification and other general purpose...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Image classification and other general purpose...
# 8                                                NaN
# 9                                                NaN
#
#                             q18_part_5 q18_part_6 q18_other
# 0                                  NaN        NaN       NaN
# 1                                  NaN        NaN       NaN
# 2                                  NaN        NaN       NaN
# 3                                  NaN        NaN       NaN
# 4                                  NaN        NaN       NaN
# 5                                  NaN        NaN       NaN
# 6                                  NaN        NaN       NaN
# 7  Generative Networks (GAN, VAE, etc)        NaN       NaN
# 8                                  NaN        NaN       NaN
# 9                                  NaN        NaN       NaN

# %%
df_q18.shape
# Out:
# (25965, 7)

# %%
# df_18_sin_nulos = df_q18.dropna(how=all )

# %%
df_q18.stb.missing()
# Out:
#             missing  total    percent
# q18_other     25846  25965  99.541691
# q18_part_6    24526  25965  94.457924
# q18_part_5    24473  25965  94.253803
# q18_part_1    23303  25965  89.747737
# q18_part_3    23249  25965  89.539765
# q18_part_2    23225  25965  89.447333
# q18_part_4    21592  25965  83.158097

# %%
df["q5_ocupacion"].value_counts()
# Out:
# Student                         6798
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2392
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1498
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: q5_ocupacion, dtype: int64

# %% [markdown]
# DF para responder a preguntas 3, sobre herramientas

# %%
df_analistas = df[df["q5_ocupacion"]== "Data Analyst"]

# %%
df_analistas.stb.missing()
# Out:
#               missing  total    percent
# q18_other        2291   2301  99.565406
# q10_part_4       2287   2301  99.391569
# q10_part_6       2286   2301  99.348110
# q10_part_13      2281   2301  99.130813
# q10_part_14      2280   2301  99.087353
# ...               ...    ...        ...
# q6_exp_tech         0   2301   0.000000
# q5_ocupacion        0   2301   0.000000
# q4_educacion        0   2301   0.000000
# q3_país             0   2301   0.000000
# q1_edad             0   2301   0.000000
#
# [89 rows x 3 columns]

# %%
df_analistas.shape
# Out:
# (2301, 89)

# %%
lista_eliminar = ['q18_part_1', 'q18_part_2', 'q18_part_3', 'q18_part_4', 'q18_part_5',
       'q18_part_6', 'q18_other',
       
       'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
       'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
       'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
       'q10_part_15', 'q10_part_16', 'q10_other', 
       
       'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
       'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other', 
       
       'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
       'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
       'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',


       'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
       'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
       'q40_part_11', 'q40_other']

# %%
df_analistas = df_analistas.drop(['q18_part_1', 'q18_part_2', 'q18_part_3', 'q18_part_4', 'q18_part_5',
       'q18_part_6', 'q18_other',
       
       'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
       'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
       'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
       'q10_part_15', 'q10_part_16', 'q10_other', 
       
       'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
       'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other', 
       
       'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
       'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
       'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',


       'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
       'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
       'q40_part_11', 'q40_other'], axis=1)

# %%
df_analistas.shape
# Out:
# (2301, 31)

# %% [markdown]
# Limpiar la columna 'Q25_salario'

# %%
df_analistas['q25_salario'].unique()
# Out:
# array(['2,000-2,999', nan, '7,500-9,999', '$0-999', '25,000-29,999',
#        '1,000-1,999', '100,000-124,999', '5,000-7,499', '10,000-14,999',
#        '15,000-19,999', '60,000-69,999', '125,000-149,999',
#        '20,000-24,999', '3,000-3,999', '4,000-4,999', '30,000-39,999',
#        '40,000-49,999', '200,000-249,999', '80,000-89,999',
#        '50,000-59,999', '70,000-79,999', '90,000-99,999',
#        '150,000-199,999', '300,000-499,999', '250,000-299,999',
#        '>$1,000,000', '$500,000-999,999'], dtype=object)

# %%
#df_analistas['q25_salario_limpia']= df_analistas['q25_salario'].apply(lambda x: x.replace("$",""))
df_analistas['q25_salario_limpia']= df_analistas['q25_salario'].replace({',':''}, regex=True)
#Si añado lo hago así, no me reemplaza el símbolo del dolar :  df_analistas['q25_salario_limpia']= df_analistas['q25_salario'].replace({',':''}, regex=True).replace({'$':''}, regex=True)

# %%
df_analistas['q25_salario_limpia'].unique()
# Out:
# array(['2000-2999', nan, '7500-9999', '$0-999', '25000-29999',
#        '1000-1999', '100000-124999', '5000-7499', '10000-14999',
#        '15000-19999', '60000-69999', '125000-149999', '20000-24999',
#        '3000-3999', '4000-4999', '30000-39999', '40000-49999',
#        '200000-249999', '80000-89999', '50000-59999', '70000-79999',
#        '90000-99999', '150000-199999', '300000-499999', '250000-299999',
#        '>$1000000', '$500000-999999'], dtype=object)

# %%
def limpia_salario(salario):
    patron = "(\d+|\d+)"
    try:
        return re.findall(patron, str(salario))
    except: 
        np.nan

# %%
df_analistas['q25_salario_limpia'] = (df_analistas['q25_salario_limpia'].apply(limpia_salario))

# %%
df_analistas['q25_salario_limpia'].unique
# Out:
# <bound method Series.unique of 16         [2000, 2999]
# 32                   []
# 33         [7500, 9999]
# 46             [0, 999]
# 52       [25000, 29999]
#               ...
# 25954          [0, 999]
# 25959          [0, 999]
# 25965                []
# 25966      [3000, 3999]
# 25968    [15000, 19999]
# Name: q25_salario_limpia, Length: 2301, dtype: object>

# %%
df_analistas['q25_salario_limpia'].head()
# Out:
# 16      [2000, 2999]
# 32                []
# 33      [7500, 9999]
# 46          [0, 999]
# 52    [25000, 29999]
# Name: q25_salario_limpia, dtype: object

# %%
for val in df_analistas['q25_salario_limpia']:
    try:
        print((int(val[0])+int(val[1]))/2)
    except:
        pass
# Out:
# 2499.5
# 8749.5
# 499.5
# 27499.5
# 499.5
# 1499.5
# 112499.5
# 1499.5
# 499.5
# 112499.5
# 6249.5
# 12499.5
# 499.5
# 2499.5
# 6249.5
# 499.5
# 499.5
# 499.5
# 12499.5
# 8749.5
# 17499.5
# 1499.5
# 12499.5
# 64999.5
# 6249.5
# 27499.5
# 6249.5
# 1499.5
# 137499.5
# 137499.5
# 22499.5
# 1499.5
# 3499.5
# 499.5
# 27499.5
# 4499.5
# 17499.5
# 499.5
# 499.5
# 64999.5
# 499.5
# 17499.5
# 499.5
# 112499.5
# 22499.5
# 499.5
# 2499.5
# 12499.5
# 34999.5
# 27499.5
# 499.5
# 34999.5
# 499.5
# 8749.5
# 22499.5
# 499.5
# 17499.5
# 499.5
# 499.5
# 499.5
# 44999.5
# 17499.5
# 499.5
# 12499.5
# 224999.5
# 499.5
# 84999.5
# 1499.5
# 499.5
# 4499.5
# 3499.5
# 499.5
# 17499.5
# 17499.5
# 84999.5
# 499.5
# 54999.5
# 499.5
# 6249.5
# 12499.5
# 499.5
# 3499.5
# 499.5
# 6249.5
# 4499.5
# 74999.5
# 6249.5
# 8749.5
# 6249.5
# 1499.5
# 499.5
# 2499.5
# 64999.5
# 1499.5
# 499.5
# 112499.5
# 499.5
# 64999.5
# 12499.5
# 12499.5
# 3499.5
# 34999.5
# 499.5
# 1499.5
# 499.5
# 499.5
# 64999.5
# 499.5
# 17499.5
# 84999.5
# 6249.5
# 499.5
# 1499.5
# 4499.5
# 2499.5
# 44999.5
# 4499.5
# 84999.5
# 499.5
# 44999.5
# 94999.5
# 499.5
# 34999.5
# 112499.5
# 499.5
# 3499.5
# 12499.5
# 112499.5
# 499.5
# 84999.5
# 8749.5
# 499.5
# 499.5
# 499.5
# 499.5
# 499.5
# 74999.5
# 499.5
# 44999.5
# 1499.5
# 12499.5
# 499.5
# 22499.5
# 499.5
# 8749.5
# 8749.5
# 6249.5
# 6249.5
# 4499.5
# 12499.5
# 27499.5
# 499.5
# 2499.5
# 112499.5
# 27499.5
# 6249.5
# 44999.5
# 499.5
# 499.5
# 12499.5
# 27499.5
# 137499.5
# 499.5
# 499.5
# 499.5
# 8749.5
# 274999.5
# 2499.5
# 94999.5
# 6249.5
# 22499.5
# 3499.5
# 2499.5
# 12499.5
# 27499.5
# 8749.5
# 2499.5
# 174999.5
# 499.5
# 54999.5
# 34999.5
# 499.5
# 499.5
# 1499.5
# 84999.5
# 2499.5
# 22499.5
# 12499.5
# 17499.5
# 1499.5
# 1499.5
# 12499.5
# 499.5
# 44999.5
# 499.5
# 34999.5
# 17499.5
# 17499.5
# 4499.5
# 44999.5
# 17499.5
# 64999.5
# 34999.5
# 8749.5
# 17499.5
# 499.5
# 499.5
# 2499.5
# 64999.5
# 3499.5
# 12499.5
# 12499.5
# 12499.5
# 74999.5
# 1499.5
# 64999.5
# 8749.5
# 8749.5
# 54999.5
# 4499.5
# 64999.5
# 6249.5
# 2499.5
# 499.5
# 499.5
# 3499.5
# 17499.5

# %%
df_analistas['q25_salario_limpia'].head
# Out:
# <bound method NDFrame.head of 16         [2000, 2999]
# 32                   []
# 33         [7500, 9999]
# 46             [0, 999]
# 52       [25000, 29999]
#               ...
# 25954          [0, 999]
# 25959          [0, 999]
# 25965                []
# 25966      [3000, 3999]
# 25968    [15000, 19999]
# Name: q25_salario_limpia, Length: 2301, dtype: object>

# %%
val
# Out:
# 17499.5

# %%
valores
# Out:
# 17499.5

# %%
df_analistas['q25_salario_limpia_media'].head()
# Out:
# 16    17499.5
# 32    17499.5
# 33    17499.5
# 46    17499.5
# 52    17499.5
# Name: q25_salario_limpia_media, dtype: float64

# %%
df_analistas.sample(10)
# Out:
#       q1_edad q2_genero                   q3_país       q4_educacion  \
# 11812   25-29       Man                 Argentina    Master’s degree
# 4911    35-39     Woman                    Mexico  Bachelor’s degree
# 17041   50-54       Man                     Italy    Master’s degree
# 24789   55-59       Man                    Russia    Master’s degree
# 5894    25-29     Woman                  Thailand    Master’s degree
# 14224   35-39       Man                 Indonesia    Master’s degree
# 3669    25-29       Man                   Germany    Master’s degree
# 18333   30-34       Man                     India    Master’s degree
# 15212   30-34     Woman  United States of America    Master’s degree
# 9787    25-29     Woman                     China    Master’s degree
#
#        q5_ocupacion                q6_exp_tech q8_l_recomendado  \
# 11812  Data Analyst                  3-5 years           Python
# 4911   Data Analyst                 5-10 years           Python
# 17041  Data Analyst                  20+ years           Python
# 24789  Data Analyst                  20+ years           Python
# 5894   Data Analyst  I have never written code              NaN
# 14224  Data Analyst                  < 1 years              SQL
# 3669   Data Analyst                  1-3 years           Python
# 18333  Data Analyst                 5-10 years           Python
# 15212  Data Analyst                  1-3 years           Python
# 9787   Data Analyst                 5-10 years           Python
#
#                                      q11_tipo_plataforma  \
# 11812  A deep learning workstation (NVIDIA GTX, Lambd...
# 4911                       A personal computer / desktop
# 17041  A cloud computing platform (AWS, Azure, GCP, h...
# 24789                      A personal computer / desktop
# 5894                                                 NaN
# 14224                                           A laptop
# 3669                                            A laptop
# 18333                                           A laptop
# 15212                                           A laptop
# 9787   A deep learning workstation (NVIDIA GTX, Lambd...
#
#                                  q20_i_actual           q21_tamanio_cia  \
# 11812                 Shipping/Transportation  10,000 or more employees
# 4911                      Academics/Education            0-49 employees
# 17041                    Computers/Technology         250-999 employees
# 24789               Manufacturing/Fabrication      1000-9,999 employees
# 5894                Government/Public Service      1000-9,999 employees
# 14224                     Academics/Education          50-249 employees
# 3669                             Retail/Sales          50-249 employees
# 18333  Online Service/Internet-based Services          50-249 employees
# 15212                  Medical/Pharmaceutical  10,000 or more employees
# 9787                      Academics/Education  10,000 or more employees
#
#       q22_da_cia    q25_salario   q26_ppto_ml_cc q33_bigdata_product  \
# 11812        20+    4,000-4,999  $10,000-$99,999              MySQL
# 4911         1-2    1,000-1,999        $100-$999                 NaN
# 17041        1-2  40,000-49,999        $100-$999                 NaN
# 24789      10-14    7,500-9,999     $1000-$9,999                 NaN
# 5894         5-9         $0-999        $0 ($USD)                 NaN
# 14224        3-4         $0-999        $0 ($USD)                 NaN
# 3669         3-4    3,000-3,999        $0 ($USD)                 NaN
# 18333        3-4  30,000-39,999        $100-$999                 NaN
# 15212        20+            NaN              NaN                 NaN
# 9787         20+    5,000-7,499     $1000-$9,999                 NaN
#
#          q35_h_i_negocios                                 q41_h_process_data  \
# 11812             Tableau  Basic statistical software (Microsoft Excel, G...
# 4911                  NaN  Local development environments (RStudio, Jupyt...
# 17041                 NaN  Basic statistical software (Microsoft Excel, G...
# 24789                 NaN  Basic statistical software (Microsoft Excel, G...
# 5894                  NaN                                                NaN
# 14224                 NaN  Basic statistical software (Microsoft Excel, G...
# 3669                  NaN  Business intelligence software (Salesforce, Ta...
# 18333  Microsoft Power BI  Basic statistical software (Microsoft Excel, G...
# 15212                 NaN                                                NaN
# 9787                  NaN  Local development environments (RStudio, Jupyt...
#
#                 q7_l_utilizados  \
# 11812               Python, SQL
# 4911                  Python, R
# 17041   Python, SQL, Java, Bash
# 24789            Python, C, C++
# 5894                        NaN
# 14224   SQL, Javascript, MATLAB
# 3669                Python, SQL
# 18333    SQL, Javascript, Other
# 15212            Python, R, SQL
# 9787           Python, SQL, C++
#
#                                                   q9_adi  \
# 11812      Visual Studio Code (VSCode) ,Jupyter Notebook
# 4911                   RStudio , Spyder,Jupyter Notebook
# 17041                         Notepad++,Jupyter Notebook
# 24789                                   Jupyter Notebook
# 5894                                                 NaN
# 14224    Visual Studio Code (VSCode) , Notepad++,MATLAB
# 3669                                    Jupyter Notebook
# 18333      Visual Studio Code (VSCode) ,Jupyter Notebook
# 15212                          RStudio ,Jupyter Notebook
# 9787   Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
#
#                                                q14_h_viz  \
# 11812                               Matplotlib ,Seaborn
# 4911    Matplotlib ,Seaborn ,Plotly / Plotly Express ...
# 17041                               Matplotlib ,Seaborn
# 24789                                        Matplotlib
# 5894                                                 NaN
# 14224                      Matplotlib ,Ggplot / ggplot2
# 3669    Matplotlib ,Seaborn ,Plotly / Plotly Express ...
# 18333                                        Matplotlib
# 15212   Matplotlib ,Plotly / Plotly Express ,Ggplot /...
# 9787                                         Matplotlib
#
#                                q42_part_1 q42_part_2 q42_part_3  \
# 11812                                 NaN        NaN        NaN
# 4911   Twitter (data science influencers)        NaN        NaN
# 17041                                 NaN        NaN        NaN
# 24789                                 NaN        NaN        NaN
# 5894                                  NaN        NaN        NaN
# 14224                                 NaN        NaN        NaN
# 3669                                  NaN        NaN        NaN
# 18333                                 NaN        NaN        NaN
# 15212                                 NaN        NaN        NaN
# 9787                                  NaN        NaN        NaN
#
#                             q42_part_4  \
# 11812  Kaggle (notebooks, forums, etc)
# 4911                               NaN
# 17041  Kaggle (notebooks, forums, etc)
# 24789  Kaggle (notebooks, forums, etc)
# 5894                               NaN
# 14224                              NaN
# 3669   Kaggle (notebooks, forums, etc)
# 18333  Kaggle (notebooks, forums, etc)
# 15212                              NaN
# 9787   Kaggle (notebooks, forums, etc)
#
#                                               q42_part_5  \
# 11812                                                NaN
# 4911                                                 NaN
# 17041                                                NaN
# 24789  Course Forums (forums.fast.ai, Coursera forums...
# 5894                                                 NaN
# 14224  Course Forums (forums.fast.ai, Coursera forums...
# 3669                                                 NaN
# 18333                                                NaN
# 15212                                                NaN
# 9787                                                 NaN
#
#                                               q42_part_6 q42_part_7  \
# 11812                                                NaN        NaN
# 4911                                                 NaN        NaN
# 17041  YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
# 24789  YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
# 5894                                                 NaN        NaN
# 14224                                                NaN        NaN
# 3669   YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
# 18333  YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
# 15212                                                NaN        NaN
# 9787                                                 NaN        NaN
#
#                                               q42_part_8 q42_part_9  \
# 11812  Blogs (Towards Data Science, Analytics Vidhya,...        NaN
# 4911                                                 NaN        NaN
# 17041  Blogs (Towards Data Science, Analytics Vidhya,...        NaN
# 24789                                                NaN        NaN
# 5894                                                 NaN        NaN
# 14224                                                NaN        NaN
# 3669   Blogs (Towards Data Science, Analytics Vidhya,...        NaN
# 18333                                                NaN        NaN
# 15212                                                NaN        NaN
# 9787                                                 NaN        NaN
#
#                                         q42_part_10 q42_part_11 q42_other
# 11812                                           NaN         NaN       NaN
# 4911                                            NaN         NaN       NaN
# 17041                                           NaN         NaN       NaN
# 24789  Slack Communities (ods.ai, kagglenoobs, etc)         NaN       NaN
# 5894                                            NaN         NaN       NaN
# 14224                                           NaN         NaN       NaN
# 3669                                            NaN         NaN       NaN
# 18333                                           NaN         NaN       NaN
# 15212                                           NaN         NaN       NaN
# 9787                                            NaN         NaN       NaN
