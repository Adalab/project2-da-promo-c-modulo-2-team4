# %%
import pandas as pd
import numpy as np
import os 
import xml.etree.ElementTree as ET

# %%
os.chdir("data")

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/garci/Documents/Adalab/proyectos/proyecto2/project2-da-promo-c-modulo-2-team4/data'

# %%
df_csv = pd.read_csv("01-data_remaning_kaggle.csv")
df_csv.head(10)
# Out:
#    Unnamed: 0  index                                         Q18_Part_1  \
# 0           0      0  General purpose image/video tools (PIL, cv2, s...
# 1           1      1                                                NaN
# 2           2      2                                                NaN
# 3           3      3  General purpose image/video tools (PIL, cv2, s...
# 4           4      4                                                NaN
# 5           5      5                                                NaN
# 6           6      6                                                NaN
# 7           7      7                                                NaN
# 8           8      8                                                NaN
# 9           9      9                                                NaN
#
#                                           Q18_Part_2  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df_exported= pd.read_csv("01-exported_db_data.csv")
df_exported.head(10)
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
# 5      5                NaN  Colab Notebooks        NaN        NaN        NaN
# 6      6   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 7      7   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 8      8   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 9      9   Kaggle Notebooks              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9  \
# 0        NaN        NaN        NaN        NaN
# ...

# %%
data_xml = pd.read_xml("01-data_xml_clean.xml")
data_xml.head()
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man
# 1        1      1   784  50-54    Man
# 2        2      2   924  22-24    Man
# 3        3      3   575  45-49    Man
# 4        4      4   781  45-49    Man

# %%
df_exported= pd.read_csv("01-data_txt_clean.txt", sep= ';')
df_exported.head()
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 3      3     Mexico    Doctoral degree       Research Scientist   20+ years
# 4      4      India    Doctoral degree                    Other   < 1 years
#
#        Q8                                                Q11  \
# 0  Python                                           A laptop
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2  Python                                           A laptop
# 3  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 4  Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                   Q13                                    Q15  \
# 0           2-5 times                             5-10 years
# ...
