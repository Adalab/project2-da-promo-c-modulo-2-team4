# %%
import pandas as pd
import re
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidetable

# %%
pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
import os

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/kuska/Documents/AnaAdalab/modulo-02/Proyecto-02/project2-da-promo-c-modulo-2-team4/04- Preguntas'

# %%
df = pd.read_csv("../data/7.dataframe_limpio.csv", index_col = 0)

# Se hace esto para resetear los índices
df.reset_index(drop=True , inplace=True)
df.head(2)
# Out:
#   q1_edad q2_genero    q3_pais       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech     q7_l_utilizados q8_l_recomendado  \
# 0  5-10 years           Python, R           Python
# 1   20+ years   SQL, C, C++, Java           Python
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                                            q14_h_viz  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q33_bigdata_product                                 q41_h_process_data  \
# 0             Unknown  Local development environments (RStudio, Jupyt...
# 1             Unknown    Advanced statistical software (SPSS, SAS, etc.)
#
#   q1_edad_new q2_genero_new q3_pais_new   q4_educacion_new  \
# 0       50-59           Man       India  Bachelor’s degree
# 1       50-59           Man       Other    Master’s degree
#
#           q5_ocupacion_new  q25_salario_new
# 0                    Other          27499.5
# 1  Program/Project Manager          64999.5

# %% [markdown]
# # 2. La industria y la presencia de trabajadores vinculados a la ciencia de datos y el aprendizaje automático

# %%
df['q20_i_actual'].value_counts().index
# Out:
# Index(['Unknown', 'Computers/Technology', 'Academics/Education',
#        'Accounting/Finance', 'Other', 'Manufacturing/Fabrication',
#        'Medical/Pharmaceutical', 'Government/Public Service',
#        'Online Service/Internet-based Services', 'Energy/Mining',
#        'Retail/Sales', 'Insurance/Risk Assessment', 'Marketing/CRM',
#        'Broadcasting/Communications', 'Shipping/Transportation',
#        'Non-profit/Service', 'Online Business/Internet-based Sales',
#        'Military/Security/Defense', 'Hospitality/Entertainment/Sports'],
#       dtype='object')

# %%
def graficar_countplot (df,lista):

    df_lista = df[lista]
    fig, axes = plt.subplots(1, len(lista), figsize=(25,6))

    for ax in fig.axes:
        ax.tick_params(labelrotation=90)
    for i in range(len(df_lista.columns)):
        sns.set_style('whitegrid')# grid
        sns.countplot(x = df_lista.columns[i], 
                        data = df, 
                        ax=axes[i],
                        palette = 'Set2')
    
    axes[0].set_title("Tipo de industria")
    axes[0].set_xlabel("Industria actual")
    
    axes[1].set_title("Tamaño de la industria")
    axes[1].set_xlabel("Tamaño de la industria")
    
    axes[2].set_title("Número de data empleados")
    axes[2].set_xlabel("Número de empleados")
    
    return plt.show();

# %%
lista_graficar = ['q20_i_actual', 'q21_tamanio_cia', 'q22_da_cia']

# %%
graficar_countplot(df,lista_graficar)

# %%
df['q20_i_actual'].value_counts().index
# Out:
# Index(['Unknown', 'Computers/Technology', 'Academics/Education',
#        'Accounting/Finance', 'Other', 'Manufacturing/Fabrication',
#        'Medical/Pharmaceutical', 'Government/Public Service',
#        'Online Service/Internet-based Services', 'Energy/Mining',
#        'Retail/Sales', 'Insurance/Risk Assessment', 'Marketing/CRM',
#        'Broadcasting/Communications', 'Shipping/Transportation',
#        'Non-profit/Service', 'Online Business/Internet-based Sales',
#        'Military/Security/Defense', 'Hospitality/Entertainment/Sports'],
#       dtype='object')

# %%
sns.set_style('whitegrid')# grid
sns.countplot(data=df , y= 'q20_i_actual',
            palette = 'Set2',
            order= ['Computers/Technology', 'Academics/Education',
                    'Accounting/Finance', 'Other', 'Manufacturing/Fabrication',
                    'Medical/Pharmaceutical', 'Government/Public Service',
                    'Online Service/Internet-based Services', 'Energy/Mining',
                    'Retail/Sales', 'Insurance/Risk Assessment', 'Marketing/CRM',
                    'Broadcasting/Communications', 'Shipping/Transportation',
                    'Non-profit/Service', 'Online Business/Internet-based Sales',
                    'Military/Security/Defense', 'Hospitality/Entertainment/Sports'])
plt.title("Industria actual")
plt.xlabel("Número de profesionales")
plt.ylabel("Industria actual")
# Out:
# Text(0, 0.5, 'Industria actual')

# %%
df_espania= df[df['q3_pais'] == 'Spain']

# %%
df_espania['q20_i_actual'].value_counts().index
# Out:
# Index(['Unknown', 'Academics/Education', 'Computers/Technology',
#        'Accounting/Finance', 'Government/Public Service',
#        'Medical/Pharmaceutical', 'Other', 'Energy/Mining',
#        'Manufacturing/Fabrication', 'Online Service/Internet-based Services',
#        'Broadcasting/Communications', 'Retail/Sales',
#        'Military/Security/Defense', 'Insurance/Risk Assessment',
#        'Marketing/CRM', 'Online Business/Internet-based Sales',
#        'Shipping/Transportation', 'Hospitality/Entertainment/Sports',
#        'Non-profit/Service'],
#       dtype='object')

# %%
sns.set_style('whitegrid')# grid
sns.countplot(data=df_espania , y= 'q20_i_actual',
            palette = 'Set2',
            order= ['Academics/Education', 'Computers/Technology',
                        'Accounting/Finance', 'Government/Public Service',
                        'Medical/Pharmaceutical', 'Other', 'Energy/Mining',
                        'Manufacturing/Fabrication', 'Online Service/Internet-based Services',
                        'Broadcasting/Communications', 'Retail/Sales',
                        'Military/Security/Defense', 'Insurance/Risk Assessment',
                        'Marketing/CRM', 'Online Business/Internet-based Sales',
                        'Shipping/Transportation', 'Hospitality/Entertainment/Sports',
                        'Non-profit/Service'])
plt.title("Industria actual, en España")
plt.xlabel("Número de profesionales")
plt.ylabel("Industria actual")
# Out:
# Text(0, 0.5, 'Industria actual')

# %%
df_analistas = df[df["q5_ocupacion"]== "Data Analyst"]

# %%
df_analistas["q20_i_actual"].value_counts().index
# Out:
# Index(['Computers/Technology', 'Academics/Education', 'Accounting/Finance',
#        'Government/Public Service', 'Other', 'Manufacturing/Fabrication',
#        'Unknown', 'Retail/Sales', 'Medical/Pharmaceutical',
#        'Online Service/Internet-based Services', 'Marketing/CRM',
#        'Energy/Mining', 'Insurance/Risk Assessment', 'Non-profit/Service',
#        'Online Business/Internet-based Sales', 'Broadcasting/Communications',
#        'Shipping/Transportation', 'Hospitality/Entertainment/Sports',
#        'Military/Security/Defense'],
#       dtype='object')

# %%
df_anali_espania= df_analistas[df_analistas['q3_pais'] == 'Spain']

# %%
df_anali_espania["q20_i_actual"].value_counts().index
# Out:
# Index(['Academics/Education', 'Retail/Sales', 'Accounting/Finance',
#        'Government/Public Service', 'Medical/Pharmaceutical', 'Energy/Mining',
#        'Computers/Technology', 'Other',
#        'Online Service/Internet-based Services', 'Unknown',
#        'Shipping/Transportation'],
#       dtype='object')

# %%
df_analistas.groupby('q20_i_actual').count().reset_index()
# Out:
#                               q20_i_actual  q1_edad  q2_genero  q3_pais  \
# 0                      Academics/Education      337        337      337
# 1                       Accounting/Finance      273        273      273
# 2              Broadcasting/Communications       50         50       50
# 3                     Computers/Technology      391        391      391
# 4                            Energy/Mining       70         70       70
# 5                Government/Public Service      139        139      139
# 6         Hospitality/Entertainment/Sports       37         37       37
# 7                Insurance/Risk Assessment       65         65       65
# 8                Manufacturing/Fabrication      116        116      116
# 9                            Marketing/CRM       87         87       87
# 10                  Medical/Pharmaceutical      106        106      106
# 11               Military/Security/Defense       19         19       19
# 12                      Non-profit/Service       59         59       59
# 13    Online Business/Internet-based Sales       54         54       54
# 14  Online Service/Internet-based Services       88         88       88
# 15                                   Other      138        138      138
# 16                            Retail/Sales      111        111      111
# 17                 Shipping/Transportation       47         47       47
# 18                                 Unknown      114        114      114
#
#     q4_educacion  q5_ocupacion  q6_exp_tech  q7_l_utilizados  \
# 0            337           337          337              337
# 1            273           273          273              273
# 2             50            50           50               50
# 3            391           391          391              391
# 4             70            70           70               70
# 5            139           139          139              139
# 6             37            37           37               37
# 7             65            65           65               65
# 8            116           116          116              116
# 9             87            87           87               87
# 10           106           106          106              106
# 11            19            19           19               19
# 12            59            59           59               59
# 13            54            54           54               54
# 14            88            88           88               88
# 15           138           138          138              138
# 16           111           111          111              111
# 17            47            47           47               47
# 18           114           114          114              114
#
#     q8_l_recomendado  q9_adi  q11_tipo_plataforma  q14_h_viz  q21_tamanio_cia  \
# 0                337     337                  337        337              337
# 1                273     273                  273        273              273
# 2                 50      50                   50         50               50
# 3                391     391                  391        391              391
# 4                 70      70                   70         70               70
# 5                139     139                  139        139              139
# 6                 37      37                   37         37               37
# 7                 65      65                   65         65               65
# 8                116     116                  116        116              116
# 9                 87      87                   87         87               87
# 10               106     106                  106        106              106
# 11                19      19                   19         19               19
# 12                59      59                   59         59               59
# 13                54      54                   54         54               54
# 14                88      88                   88         88               88
# 15               138     138                  138        138              138
# 16               111     111                  111        111              111
# 17                47      47                   47         47               47
# 18               114     114                  114        114              114
#
#     q22_da_cia  q25_salario  q33_bigdata_product  q41_h_process_data  \
# 0          337          337                  337                 337
# 1          273          273                  273                 273
# 2           50           50                   50                  50
# 3          391          391                  391                 391
# 4           70           70                   70                  70
# 5          139          139                  139                 139
# 6           37           37                   37                  37
# 7           65           65                   65                  65
# 8          116          116                  116                 116
# 9           87           87                   87                  87
# 10         106          106                  106                 106
# 11          19           19                   19                  19
# 12          59           59                   59                  59
# 13          54           54                   54                  54
# 14          88           88                   88                  88
# 15         138          138                  138                 138
# 16         111          111                  111                 111
# 17          47           47                   47                  47
# 18         114          114                  114                 114
#
#     q1_edad_new  q2_genero_new  q3_pais_new  q4_educacion_new  \
# 0           337            337          337               337
# 1           273            273          273               273
# 2            50             50           50                50
# 3           391            391          391               391
# 4            70             70           70                70
# 5           139            139          139               139
# 6            37             37           37                37
# 7            65             65           65                65
# 8           116            116          116               116
# 9            87             87           87                87
# 10          106            106          106               106
# 11           19             19           19                19
# 12           59             59           59                59
# 13           54             54           54                54
# 14           88             88           88                88
# 15          138            138          138               138
# 16          111            111          111               111
# 17           47             47           47                47
# 18          114            114          114               114
#
#     q5_ocupacion_new  q25_salario_new
# 0                337              337
# 1                273              273
# 2                 50               50
# 3                391              391
# 4                 70               70
# 5                139              139
# 6                 37               37
# 7                 65               65
# 8                116              116
# 9                 87               87
# 10               106              106
# 11                19               19
# 12                59               59
# 13                54               54
# 14                88               88
# 15               138              138
# 16               111              111
# 17                47               47
# 18               114              114

# %% [markdown]
# ## ¿En qué industria existe mayor número de analistas de datos?

# %%
sns.set_theme(style="whitegrid")# grid
g = sns.countplot(data=df_analistas , y= 'q20_i_actual',
            palette = 'Set2',
            order= ['Computers/Technology', 'Academics/Education', 'Accounting/Finance',
                'Government/Public Service', 'Other', 'Manufacturing/Fabrication', 'Retail/Sales', 'Medical/Pharmaceutical',
                'Online Service/Internet-based Services', 'Marketing/CRM',
                'Energy/Mining', 'Insurance/Risk Assessment', 'Non-profit/Service',
                'Online Business/Internet-based Sales', 'Broadcasting/Communications',
                'Shipping/Transportation', 'Hospitality/Entertainment/Sports',
                'Military/Security/Defense'])
                    
plt.title('Número de analistas de datos según tipo de industria')
plt.xlabel('Número de analistas') # definir el nombre del eje X
plt.ylabel('Industria') # definir el nombre del eje Y
plt.savefig("graficas/20-2-Número de analistas por industria.png")

# %%
sns.set_theme(style="whitegrid")# grid
g = sns.countplot(data=df_espania , y= 'q20_i_actual',
            palette = 'Set2',
            order = ['Academics/Education', 'Computers/Technology', 'Accounting/Finance',
                'Government/Public Service', 'Medical/Pharmaceutical','Energy/Mining',
                'Online Service/Internet-based Services',
                'Retail/Sales',
                'Shipping/Transportation'])
                    
plt.title('Número de analistas de datos según tipo de industria, de España')
plt.xlabel('Número de analistas') # definir el nombre del eje X
plt.ylabel('Industria') # definir el nombre del eje Y
plt.savefig("graficas/20-22-Número de analistas por industria.png")

# %% [markdown]
# # ¿Qué industria paga mejor a los Data Anlalyst?

# %%
df_industria = df_analistas.groupby('q20_i_actual').mean()
df_industria.reset_index(inplace=True)
df_industria.head()
# Out:
# /tmp/ipykernel_1599/2389554831.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_industria = df_analistas.groupby('q20_i_actual').mean()
#                   q20_i_actual  q25_salario_new
# 0          Academics/Education     37493.070139
# 1           Accounting/Finance     38757.529767
# 2  Broadcasting/Communications     35007.220328
# 3         Computers/Technology     34521.451757
# 4                Energy/Mining     34385.600384

# %%
df_industria_ordenado = df_industria.sort_values('q25_salario_new', ascending = False)

# %%
sns.barplot(y='q20_i_actual', x = 'q25_salario_new', data= df_industria_ordenado, palette = 'Set2')
plt.title('Salario de los analistas de datos según tipo de industria')
plt.xlabel('Promedio de salario anual') # definir el nombre del eje X
plt.ylabel('Industria') # definir el nombre del eje Y
# plt.legend(facecolor='gray', loc="lower right")
plt.savefig("graficas/20-2-Salario analistas por industria.png");

# %% [markdown]
# # Para ver las industrias, en España, que mejor pagan:

# %%
df_españa_ind = df_analistas[df_analistas['q3_pais'] == 'Spain']

# %%
df_industria2 = df_españa_ind.groupby('q20_i_actual').mean()
df_industria2.reset_index(inplace=True)
df_industria2.head(20)
# Out:
# /tmp/ipykernel_1599/148712289.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_industria2 = df_españa_ind.groupby('q20_i_actual').mean()
#                               q20_i_actual  q25_salario_new
# 0                      Academics/Education     24271.500260
# 1                       Accounting/Finance     41666.166667
# 2                     Computers/Technology     28299.000585
# 3                            Energy/Mining     44549.000585
# 4                Government/Public Service     69999.500000
# 5                   Medical/Pharmaceutical     26874.500000
# 6   Online Service/Internet-based Services     64999.500000
# 7                                    Other     11499.500000
# 8                             Retail/Sales     48865.833723
# 9                  Shipping/Transportation    174999.500000
# 10                                 Unknown     44098.501170

# %%
df_industria_ordenado_esp = df_industria2.sort_values('q25_salario_new', ascending = False)

# %%
plt.figure(figsize= (8,5))
sns.set_theme(style="whitegrid")# grid
sns.barplot(y='q20_i_actual', x = 'q25_salario_new', data= df_industria_ordenado_esp , palette = 'Set2')
plt.title('Salario de los analistas de datos según tipo de industria, en España')
plt.xlabel('Promedio de salario anual') # definir el nombre del eje X
plt.ylabel('Industria') # definir el nombre del eje Y
# plt.legend(facecolor='gray', loc="lower right")
plt.savefig("graficas/20-3-Salario analistas por industria.png");

# %% [markdown]
# ## ¿Y como está colocado el analista de datos respecto a otros puestos en cuánto a salario?

# %%
df_salario_ocupacion = df.groupby('q5_ocupacion').mean()
df_salario_ocupacion.reset_index(inplace=True)
df_salario_ocupacion['q5_ocupacion'].unique()
# Out:
# /tmp/ipykernel_1599/3797353196.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_salario_ocupacion = df.groupby('q5_ocupacion').mean()
# array(['Business Analyst', 'Currently not employed',
#        'DBA/Database Engineer', 'Data Analyst', 'Data Engineer',
#        'Data Scientist', 'Developer Relations/Advocacy',
#        'Machine Learning Engineer', 'Other', 'Product Manager',
#        'Program/Project Manager', 'Research Scientist',
#        'Software Engineer', 'Statistician', 'Student'], dtype=object)

# %%
df_salario_ocupacion = df_salario_ocupacion[(df_salario_ocupacion['q5_ocupacion'] != 'Student') & (df_salario_ocupacion['q5_ocupacion'] != 'Currently not employed') ]
df_ocu_ordenado = df_salario_ocupacion.sort_values('q25_salario_new', ascending = False)

# %%
plt.figure(figsize= (8,5))
sns.set_theme(style="whitegrid")# grid
sns.barplot(y='q5_ocupacion', x = 'q25_salario_new', data= df_ocu_ordenado , palette = 'Set2')
plt.title('Comparación del salario entre los diferentes puestos de la industria')
plt.xlabel('Promedio de salario anual') # definir el nombre del eje X
plt.ylabel('Ocupación') # definir el nombre del eje Y
# plt.legend(facecolor='gray', loc="lower right")
plt.savefig("graficas/20-4-Puestos analistas por industria.png");

# %%
df_an_genero_sal = df_analistas.groupby('q2_genero_new').mean().reset_index()
df_gen_ordenado = df_an_genero_sal.sort_values('q25_salario_new', ascending = False).reset_index()
# Out:
# /tmp/ipykernel_1599/2701424607.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_an_genero_sal = df_analistas.groupby('q2_genero_new').mean().reset_index()

# %% [markdown]
# ## ¿Y la brecha de género en el salario?

# %%
plt.figure(figsize= (8,5))
sns.set_theme(style="whitegrid")# grid
sns.barplot(y='q2_genero_new', x = 'q25_salario_new', data= df_gen_ordenado , palette = 'Set2')
plt.title('Salarios según el género')
plt.xlabel('Promedio de salario anual') # definir el nombre del eje X
plt.ylabel('Género') # definir el nombre del eje Y
# plt.legend(facecolor='gray', loc="lower right")
plt.savefig("graficas/20-5-Puestos analistas por industria.png");

plt.show()

# %%
for i, column in enumerate(df["q25_salario_new"]):
    sns.boxplot(x=df[column], data=df, ax=ax[i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 27499.5
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [28], line 2
#       1 for i, column in enumerate(df["q25_salario_new"]):
# ----> 2     sns.boxplot(x=df[column], data=df, ax=ax[i])
#       3     plt.show()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 27499.5

# %%
sns.violinplot ( x="q2_genero_new" , y= "q25_salario_new", data= df_analistas, hist=True, kde=False, rug=False)
# Out:
# <AxesSubplot:xlabel='q2_genero_new', ylabel='q25_salario_new'>

# %% [markdown]
# # ¿Cuántos analistas de datos en relación al tamaño de la empresa?

# %%
plt.figure(figsize= (20,7))
sns.set_theme(style="whitegrid")# grid
sns.countplot(x = 'q21_tamanio_cia', 
            data=df_analistas, 
            palette = 'husl',
            order=['1000-9,999 employees','250-999 employees','0-49 employees','10,000 or more employees','50-249 employees'])
plt.title("Analistas en las empresas")
plt.ylabel("Tamaño de la empresa")
plt.xlabel("Número de analistas")
# plt.legend((['Man','Woman','Others']))
# Out:
# Text(0.5, 0, 'Número de analistas')

# %% [markdown]
# # ¿Cuántos analistas de datos en relación al tamaño de la empresa, es una condición el género?

# %%
plt.figure(figsize= (20,7))
sns.set_theme(style="whitegrid")# grid
sns.countplot(y = 'q21_tamanio_cia', 
data=df_analistas, 
hue = 'q2_genero_new', 
palette = 'Set2',
order=['0-49 employees','50-249 employees','250-999 employees','1000-9,999 employees','10,000 or more employees','Unknown'])
plt.title("Analistas en las empresas")
plt.ylabel("Tamaño de la empresa")
plt.xlabel("Número de analistas")
plt.legend((['Man','Others','Woman']))

# %%
def graficar_countplot (df,lista):
    df_lista = df[lista]
    fig, axes = plt.subplots(1, len(lista), figsize=(25,6))
    for ax in fig.axes:
        ax.tick_params(labelrotation=90)
    for i in range(len(df_lista.columns)):
        sns.countplot(x = df_lista.columns[i], data = df, ax=axes[i], hue="q2_genero_new");
    return plt.show();

# %%
columnas_graficos1=['q20_i_actual','q25_salario_new']

# %%
columnas_g2 = ['q21_tamanio_cia','q2_genero_new']

# %%
graficar_countplot(df,columnas_graficos1)

# %%
graficar_countplot(df_analistas,columnas_g2)

# %% [markdown]
# A modo de resumen podemos ver los hombres dominan el mundo del data, y que en la mayoria de las empresas el equipo de analistas en la mayoria de las empreas es pequeño y suele estar dominado por hombres.
