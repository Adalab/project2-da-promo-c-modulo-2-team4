# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidetable

# %%
pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
df = pd.read_csv("../data/6.dataframe_analisis.csv", index_col = 0)

# Se hace esto para resetear los índices
df.reset_index(drop=True , inplace=True)
df.head(2)
# Out:
#   q1_edad q2_genero    q3_pais       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech q8_l_recomendado  \
# 0  5-10 years           Python
# 1   20+ years           Python
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# 0      $100-$999                 NaN              NaN
# 1      $0 ($USD)                 NaN              NaN
#
#                                   q41_h_process_data     q7_l_utilizados  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                            q14_h_viz         q10_part_1  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                        Matplotlib    Kaggle Notebooks
#
#         q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# 0  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#   q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
#
#   q10_part_14 q10_part_15 q10_part_16 q10_other  \
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
#
#                                           q18_part_1 q18_part_2 q18_part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1 q27_a_part_2  \
# 0        NaN        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN        NaN       NaN          NaN          NaN
#
#                     q27_a_part_3 q27_a_part_4 q27_a_part_5 q27_a_part_6  \
# 0   Google Cloud Platform (GCP)           NaN          NaN          NaN
# 1                            NaN          NaN          NaN          NaN
#
#   q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10 q27_a_part_11  \
# 0          NaN          NaN          NaN           NaN           NaN
# 1          NaN          NaN          NaN           NaN           NaN
#
#   q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4 q39_part_5  \
# 0         NaN        NaN        NaN        NaN    GitHub         NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
#
#   q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other q40_part_1 q40_part_2  \
# 0    Kaggle         NaN        NaN        NaN       NaN   Coursera        edX
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
#
#              q40_part_3 q40_part_4 q40_part_5 q40_part_6 q40_part_7  \
# 0  Kaggle Learn Courses   DataCamp        NaN    Udacity      Udemy
# 1  Kaggle Learn Courses        NaN        NaN        NaN        NaN
#
#   q40_part_8                                         q40_part_9  \
# 0        NaN                                                NaN
# 1        NaN  Cloud-certification programs (direct from AWS,...
#
#                                          q40_part_10 q40_part_11 q40_other  \
# 0                                                NaN         NaN       NaN
# 1  University Courses (resulting in a university ...         NaN       NaN
#
#   q42_part_1                                         q42_part_2 q42_part_3  \
# 0        NaN  Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 1        NaN                                                NaN        NaN
#
#                         q42_part_4 q42_part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
#
#                                           q42_part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
#
#                                           q42_part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
#
#                                           q42_part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
#
#                                           q42_part_9 q42_part_10 q42_part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   q42_other
# 0       NaN
# 1       NaN

# %%
lista_eliminar= ['q20_i_actual', 'q21_tamanio_cia', 'q22_da_cia']

# %%
df.drop(columns = lista_eliminar, axis=1, inplace=True)

# %%
df_analista = df[df['q5_ocupacion'] == 'Data Analyst']

# %%
df_analista_España= df_analista[df_analista['q3_pais'] == 'Spain']

# %%
df_analista_sinEspaña_sinOther= df_analista[(df_analista['q3_pais'] != 'Spain') & (df_analista['q3_pais'] != 'Other')]

# %%
df_analista_sinOther= df_analista[df_analista['q3_pais'] != 'Other']

# %%
df_analista.stb.freq(['q3_pais'])[:31]
# Out:
#                                               q3_pais  count    percent  \
# 0                                               India    564  24.511082
# 1                            United States of America    258  11.212516
# 2                                               Other    135   5.867014
# 3                                             Nigeria    102   4.432855
# 4                                               China     94   4.085180
# 5                                               Egypt     87   3.780965
# 6                                              Russia     68   2.955237
# 7                                              Brazil     64   2.781399
# 8   United Kingdom of Great Britain and Northern I...     53   2.303346
# 9                                               Japan     46   1.999131
# 10                                          Indonesia     42   1.825293
# 11                                           Pakistan     39   1.694915
# 12                                          Australia     38   1.651456
# 13                                              Kenya     37   1.607997
# 14                                             Canada     36   1.564537
# 15                                            Germany     34   1.477618
# 16                                             Taiwan     30   1.303781
# 17                                        South Korea     30   1.303781
# 18                                             Mexico     30   1.303781
# 19                                             France     29   1.260322
# 20                                           Colombia     29   1.260322
# 21                                              Spain     28   1.216862
# 22                                             Turkey     27   1.173403
# 23                                             Poland     22   0.956106
# 24                                         Bangladesh     22   0.956106
# 25                                          Argentina     22   0.956106
# 26                                            Ukraine     21   0.912647
# 27                                               Peru     21   0.912647
# 28                                           Viet Nam     20   0.869187
# 29                                          Singapore     20   0.869187
# 30                                           Thailand     15   0.651890
#
#     cumulative_count  cumulative_percent
# 0                564           24.511082
# 1                822           35.723598
# 2                957           41.590613
# 3               1059           46.023468
# 4               1153           50.108648
# 5               1240           53.889613
# 6               1308           56.844850
# 7               1372           59.626249
# 8               1425           61.929596
# 9               1471           63.928727
# 10              1513           65.754020
# 11              1552           67.448935
# 12              1590           69.100391
# 13              1627           70.708388
# 14              1663           72.272925
# 15              1697           73.750543
# 16              1727           75.054324
# 17              1757           76.358105
# 18              1787           77.661886
# 19              1816           78.922208
# 20              1845           80.182529
# 21              1873           81.399392
# 22              1900           82.572794
# 23              1922           83.528900
# 24              1944           84.485007
# 25              1966           85.441113
# 26              1987           86.353759
# 27              2008           87.266406
# 28              2028           88.135593
# 29              2048           89.004781
# 30              2063           89.656671

# %%
df_analista_sinOther.reset_index
# Out:
# <bound method DataFrame.reset_index of       q1_edad  q2_genero                   q3_pais  \
# 16      50-54        Man                   Belgium
# 32      22-24  Nonbinary  United States of America
# 33      30-34      Woman                     Egypt
# 46      22-24        Man                     China
# 52      40-44        Man              South Africa
# ...       ...        ...                       ...
# 25954   25-29        Man                     India
# 25959   18-21        Man                     India
# 25965   18-21        Man                     India
# 25966   30-34        Man                     India
# 25968   30-34        Man                     Egypt
#
#                                             q4_educacion  q5_ocupacion  \
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
# 46     Some college/university study without earning ...  Data Analyst
# 52                                       Master’s degree  Data Analyst
# ...                                                  ...           ...
# 25954                             Professional doctorate  Data Analyst
# 25959                                  Bachelor’s degree  Data Analyst
# 25965                                    Master’s degree  Data Analyst
# 25966                                  Bachelor’s degree  Data Analyst
# 25968                                  Bachelor’s degree  Data Analyst
#
#       q6_exp_tech q8_l_recomendado  \
# 16      20+ years           Python
# 32      < 1 years                R
# 33      3-5 years                R
# 46      < 1 years           Python
# 52      1-3 years                R
# ...           ...              ...
# 25954   < 1 years           Python
# 25959   1-3 years           Python
# 25965   1-3 years           Python
# 25966   1-3 years           Python
# 25968   1-3 years           Python
#
#                                      q11_tipo_plataforma    q25_salario  \
# 16                                              A laptop    2,000-2,999
# 32                         A personal computer / desktop            NaN
# 33                                              A laptop    7,500-9,999
# 46                         A personal computer / desktop         $0-999
# 52                                              A laptop  25,000-29,999
# ...                                                  ...            ...
# 25954                                           A laptop         $0-999
# 25959                      A personal computer / desktop         $0-999
# 25965                      A personal computer / desktop            NaN
# 25966  A cloud computing platform (AWS, Azure, GCP, h...    3,000-3,999
# 25968                                           A laptop  15,000-19,999
#
#       q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# 16         $0 ($USD)                 NaN              NaN
# 32               NaN                 NaN              NaN
# 33         $0 ($USD)                 NaN              NaN
# 46         $0 ($USD)                 NaN              NaN
# 52         $100-$999                 NaN              NaN
# ...              ...                 ...              ...
# 25954      $0 ($USD)                 NaN              NaN
# 25959      $0 ($USD)                 NaN              NaN
# 25965            NaN                 NaN              NaN
# 25966      $100-$999                 NaN              NaN
# 25968   $1000-$9,999            MongoDB               NaN
#
#                                       q41_h_process_data  \
# 16     Local development environments (RStudio, Jupyt...
# 32                                                   NaN
# 33     Basic statistical software (Microsoft Excel, G...
# 46     Basic statistical software (Microsoft Excel, G...
# 52     Local development environments (RStudio, Jupyt...
# ...                                                  ...
# 25954                                                NaN
# 25959  Business intelligence software (Salesforce, Ta...
# 25965                                                NaN
# 25966                                                NaN
# 25968  Business intelligence software (Salesforce, Ta...
#
#                                      q7_l_utilizados  \
# 16                                       Python, SQL
# 32                                                 R
# 33                                            Python
# 46     Python, SQL, C, C++, Java, Javascript, MATLAB
# 52                                            R, SQL
# ...                                              ...
# 25954                                         Python
# 25959                                    Python, SQL
# 25965                                 Python, SQL, C
# 25966                                      Python, C
# 25968                  Python, SQL, Javascript, Bash
#
#                                                   q9_adi  \
# 16     Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 32                                              RStudio
# 33                            Notepad++,Jupyter Notebook
# 46     Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 52                             RStudio ,Jupyter Notebook
# ...                                                  ...
# 25954                                   Jupyter Notebook
# 25959  Visual Studio ,Visual Studio Code (VSCode) ,Ju...
# 25965  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 25966                          PyCharm ,Jupyter Notebook
# 25968  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
#
#                                                q14_h_viz         q10_part_1  \
# 16         Matplotlib ,Seaborn ,Plotly / Plotly Express    Kaggle Notebooks
# 32                                     Ggplot / ggplot2                 NaN
# 33                                                  None   Kaggle Notebooks
# 46                  Matplotlib ,Plotly / Plotly Express    Kaggle Notebooks
# 52     Plotly / Plotly Express ,Ggplot / ggplot2 ,Shiny                 NaN
# ...                                                  ...                ...
# 25954                                        Matplotlib                 NaN
# 25959                        Matplotlib ,Seaborn , Other   Kaggle Notebooks
# 25965      Matplotlib ,Seaborn ,Plotly / Plotly Express    Kaggle Notebooks
# 25966             Matplotlib ,Seaborn ,Ggplot / ggplot2                 NaN
# 25968                               Matplotlib ,Seaborn                 NaN
#
#             q10_part_2       q10_part_3 q10_part_4             q10_part_5  \
# 16     Colab Notebooks              NaN        NaN                    NaN
# 32                 NaN              NaN        NaN                    NaN
# 33     Colab Notebooks              NaN        NaN                    NaN
# 46                 NaN  Azure Notebooks        NaN                    NaN
# 52                 NaN              NaN        NaN                    NaN
# ...                ...              ...        ...                    ...
# 25954              NaN              NaN        NaN   Binder / JupyterHub
# 25959  Colab Notebooks              NaN        NaN                    NaN
# 25965  Colab Notebooks              NaN        NaN                    NaN
# 25966              NaN              NaN        NaN                    NaN
# 25968  Colab Notebooks              NaN        NaN                    NaN
#
#       q10_part_6           q10_part_7                           q10_part_8  \
# 16           NaN                  NaN                                  NaN
# 32           NaN                  NaN                                  NaN
# 33           NaN                  NaN                                  NaN
# 46           NaN                  NaN                                  NaN
# 52           NaN   IBM Watson Studio                                   NaN
# ...          ...                  ...                                  ...
# 25954        NaN                  NaN                                  NaN
# 25959        NaN                  NaN                                  NaN
# 25965        NaN                  NaN                                  NaN
# 25966        NaN                  NaN                                  NaN
# 25968        NaN                  NaN   Amazon Sagemaker Studio Notebooks
#
#                    q10_part_9  \
# 16                        NaN
# 32                        NaN
# 33                        NaN
# 46                        NaN
# 52                        NaN
# ...                       ...
# 25954                     NaN
# 25959                     NaN
# 25965                     NaN
# 25966                     NaN
# 25968   Amazon EMR Notebooks
#
#                                              q10_part_10  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954                                                NaN
# 25959  Google Cloud Notebooks (AI Platform / Vertex AI)
# 25965                                                NaN
# 25966                                                NaN
# 25968                                                NaN
#
#                 q10_part_11                           q10_part_12 q10_part_13  \
# 16                      NaN   Databricks Collaborative Notebooks          NaN
# 32     Google Cloud Datalab                                   NaN         NaN
# 33                      NaN                                   NaN         NaN
# 46                      NaN                                   NaN         NaN
# 52                      NaN                                   NaN         NaN
# ...                     ...                                   ...         ...
# 25954                   NaN                                   NaN         NaN
# 25959                   NaN                                   NaN         NaN
# 25965                   NaN                                   NaN         NaN
# 25966  Google Cloud Datalab                                   NaN         NaN
# 25968                   NaN   Databricks Collaborative Notebooks          NaN
#
#       q10_part_14 q10_part_15 q10_part_16 q10_other  \
# 16            NaN         NaN         NaN       NaN
# 32            NaN         NaN         NaN       NaN
# 33            NaN         NaN         NaN       NaN
# 46            NaN         NaN         NaN       NaN
# 52            NaN         NaN         NaN       NaN
# ...           ...         ...         ...       ...
# 25954         NaN         NaN         NaN       NaN
# 25959         NaN         NaN         NaN       NaN
# 25965         NaN         NaN         NaN       NaN
# 25966         NaN         NaN         NaN       NaN
# 25968         NaN         NaN         NaN       NaN
#
#                                               q18_part_1  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954                                                NaN
# 25959                                                NaN
# 25965  General purpose image/video tools (PIL, cv2, s...
# 25966  General purpose image/video tools (PIL, cv2, s...
# 25968  General purpose image/video tools (PIL, cv2, s...
#
#                                               q18_part_2  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954  Image segmentation methods (U-Net, Mask R-CNN,...
# 25959                                                NaN
# 25965  Image segmentation methods (U-Net, Mask R-CNN,...
# 25966  Image segmentation methods (U-Net, Mask R-CNN,...
# 25968                                                NaN
#
#                                               q18_part_3  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954                                                NaN
# 25959                                                NaN
# 25965  Object detection methods (YOLOv3, RetinaNet, etc)
# 25966  Object detection methods (YOLOv3, RetinaNet, etc)
# 25968  Object detection methods (YOLOv3, RetinaNet, etc)
#
#                                               q18_part_4  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954                                                NaN
# 25959                                                NaN
# 25965  Image classification and other general purpose...
# 25966  Image classification and other general purpose...
# 25968  Image classification and other general purpose...
#
#                                 q18_part_5 q18_part_6 q18_other  \
# 16                                     NaN        NaN       NaN
# 32                                     NaN        NaN       NaN
# 33                                     NaN        NaN       NaN
# 46                                     NaN        NaN       NaN
# 52                                     NaN        NaN       NaN
# ...                                    ...        ...       ...
# 25954                                  NaN        NaN       NaN
# 25959                                  NaN        NaN       NaN
# 25965                                  NaN        NaN       NaN
# 25966  Generative Networks (GAN, VAE, etc)        NaN       NaN
# 25968                                  NaN        NaN       NaN
#
#                       q27_a_part_1       q27_a_part_2 q27_a_part_3  \
# 16                             NaN                NaN          NaN
# 32                             NaN                NaN          NaN
# 33                             NaN                NaN          NaN
# 46                             NaN                NaN          NaN
# 52                             NaN                NaN          NaN
# ...                            ...                ...          ...
# 25954                          NaN                NaN          NaN
# 25959                          NaN                NaN          NaN
# 25965                          NaN                NaN          NaN
# 25966                          NaN                NaN          NaN
# 25968   Amazon Web Services (AWS)    Microsoft Azure           NaN
#
#                 q27_a_part_4 q27_a_part_5 q27_a_part_6 q27_a_part_7  \
# 16                       NaN          NaN          NaN          NaN
# 32                       NaN          NaN          NaN          NaN
# 33                       NaN          NaN          NaN          NaN
# 46                       NaN          NaN          NaN          NaN
# 52      IBM Cloud / Red Hat           NaN          NaN          NaN
# ...                      ...          ...          ...          ...
# 25954                    NaN          NaN          NaN          NaN
# 25959                    NaN          NaN          NaN          NaN
# 25965                    NaN          NaN          NaN          NaN
# 25966                    NaN          NaN          NaN          NaN
# 25968                    NaN          NaN          NaN          NaN
#
#       q27_a_part_8 q27_a_part_9 q27_a_part_10 q27_a_part_11 q27_a_other  \
# 16             NaN          NaN           NaN           NaN         NaN
# 32             NaN          NaN           NaN           NaN         NaN
# 33             NaN          NaN           NaN          None         NaN
# 46             NaN          NaN           NaN           NaN         NaN
# 52             NaN          NaN           NaN           NaN         NaN
# ...            ...          ...           ...           ...         ...
# 25954          NaN          NaN           NaN           NaN         NaN
# 25959          NaN          NaN           NaN           NaN         NaN
# 25965          NaN          NaN           NaN           NaN         NaN
# 25966          NaN          NaN           NaN           NaN         NaN
# 25968          NaN          NaN           NaN           NaN         NaN
#
#       q39_part_1 q39_part_2 q39_part_3 q39_part_4 q39_part_5 q39_part_6  \
# 16           NaN        NaN        NaN        NaN        NaN        NaN
# 32           NaN        NaN        NaN        NaN        NaN        NaN
# 33           NaN        NaN        NaN        NaN        NaN        NaN
# 46           NaN        NaN        NaN        NaN        NaN        NaN
# 52           NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 25954        NaN        NaN        NaN        NaN        NaN        NaN
# 25959        NaN        NaN        NaN        NaN        NaN        NaN
# 25965        NaN        NaN        NaN        NaN        NaN        NaN
# 25966        NaN        NaN        NaN        NaN        NaN        NaN
# 25968        NaN        NaN        NaN    GitHub         NaN        NaN
#
#       q39_part_7 q39_part_8                       q39_part_9 q39_other  \
# 16           NaN        NaN                              NaN       NaN
# 32           NaN        NaN                              NaN       NaN
# 33           NaN        NaN  I do not share my work publicly       NaN
# 46           NaN        NaN                              NaN       NaN
# 52           NaN        NaN  I do not share my work publicly       NaN
# ...          ...        ...                              ...       ...
# 25954        NaN        NaN                              NaN       NaN
# 25959        NaN        NaN                              NaN       NaN
# 25965        NaN        NaN                              NaN       NaN
# 25966        NaN        NaN                              NaN       NaN
# 25968     Colab         NaN                              NaN       NaN
#
#       q40_part_1 q40_part_2            q40_part_3 q40_part_4 q40_part_5  \
# 16      Coursera        NaN  Kaggle Learn Courses        NaN        NaN
# 32           NaN        NaN                   NaN        NaN        NaN
# 33      Coursera        NaN  Kaggle Learn Courses   DataCamp        NaN
# 46      Coursera        edX  Kaggle Learn Courses        NaN        NaN
# 52      Coursera        NaN                   NaN        NaN        NaN
# ...          ...        ...                   ...        ...        ...
# 25954   Coursera        NaN                   NaN        NaN        NaN
# 25959   Coursera        edX                   NaN        NaN        NaN
# 25965        NaN        NaN                   NaN        NaN        NaN
# 25966        NaN        NaN                   NaN        NaN        NaN
# 25968   Coursera        NaN  Kaggle Learn Courses   DataCamp        NaN
#
#       q40_part_6 q40_part_7         q40_part_8  \
# 16           NaN        NaN                NaN
# 32           NaN        NaN                NaN
# 33           NaN        NaN                NaN
# 46           NaN        NaN                NaN
# 52           NaN      Udemy                NaN
# ...          ...        ...                ...
# 25954        NaN        NaN                NaN
# 25959    Udacity      Udemy                NaN
# 25965        NaN        NaN                NaN
# 25966        NaN        NaN                NaN
# 25968    Udacity      Udemy  LinkedIn Learning
#
#                                               q40_part_9  \
# 16     Cloud-certification programs (direct from AWS,...
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954                                                NaN
# 25959  Cloud-certification programs (direct from AWS,...
# 25965                                                NaN
# 25966                                                NaN
# 25968  Cloud-certification programs (direct from AWS,...
#
#                                              q40_part_10 q40_part_11  \
# 16                                                   NaN         NaN
# 32                                                   NaN         NaN
# 33     University Courses (resulting in a university ...         NaN
# 46                                                   NaN         NaN
# 52                                                   NaN         NaN
# ...                                                  ...         ...
# 25954                                                NaN         NaN
# 25959  University Courses (resulting in a university ...         NaN
# 25965                                                NaN         NaN
# 25966                                                NaN         NaN
# 25968                                                NaN         NaN
#
#       q40_other                          q42_part_1  \
# 16          NaN                                 NaN
# 32          NaN                                 NaN
# 33        Other  Twitter (data science influencers)
# 46          NaN  Twitter (data science influencers)
# 52          NaN                                 NaN
# ...         ...                                 ...
# 25954       NaN                                 NaN
# 25959       NaN  Twitter (data science influencers)
# 25965       NaN                                 NaN
# 25966       NaN                                 NaN
# 25968       NaN                                 NaN
#
#                                               q42_part_2 q42_part_3  \
# 16                                                   NaN        NaN
# 32                                                   NaN        NaN
# 33     Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 46                                                   NaN        NaN
# 52                                                   NaN        NaN
# ...                                                  ...        ...
# 25954                                                NaN        NaN
# 25959  Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 25965                                                NaN        NaN
# 25966                                                NaN        NaN
# 25968                                                NaN        NaN
#
#                             q42_part_4  \
# 16     Kaggle (notebooks, forums, etc)
# 32                                 NaN
# 33     Kaggle (notebooks, forums, etc)
# 46     Kaggle (notebooks, forums, etc)
# 52                                 NaN
# ...                                ...
# 25954                              NaN
# 25959                              NaN
# 25965                              NaN
# 25966                              NaN
# 25968  Kaggle (notebooks, forums, etc)
#
#                                               q42_part_5  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52     Course Forums (forums.fast.ai, Coursera forums...
# ...                                                  ...
# 25954                                                NaN
# 25959  Course Forums (forums.fast.ai, Coursera forums...
# 25965                                                NaN
# 25966                                                NaN
# 25968                                                NaN
#
#                                               q42_part_6 q42_part_7  \
# 16                                                   NaN        NaN
# 32                                                   NaN        NaN
# 33     YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
# 46     YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
# 52     YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
# ...                                                  ...        ...
# 25954                                                NaN        NaN
# 25959  YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
# 25965                                                NaN        NaN
# 25966                                                NaN        NaN
# 25968  YouTube (Kaggle YouTube, Cloud AI Adventures, ...        NaN
#
#                                               q42_part_8  \
# 16     Blogs (Towards Data Science, Analytics Vidhya,...
# 32                                                   NaN
# 33     Blogs (Towards Data Science, Analytics Vidhya,...
# 46                                                   NaN
# 52     Blogs (Towards Data Science, Analytics Vidhya,...
# ...                                                  ...
# 25954                                                NaN
# 25959  Blogs (Towards Data Science, Analytics Vidhya,...
# 25965                                                NaN
# 25966                                                NaN
# 25968                                                NaN
#
#                                               q42_part_9  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954                                                NaN
# 25959  Journal Publications (peer-reviewed journals, ...
# 25965                                                NaN
# 25966                                                NaN
# 25968                                                NaN
#
#                                         q42_part_10 q42_part_11 q42_other
# 16                                              NaN         NaN       NaN
# 32                                              NaN         NaN       NaN
# 33                                              NaN         NaN       NaN
# 46                                              NaN         NaN       NaN
# 52     Slack Communities (ods.ai, kagglenoobs, etc)         NaN       NaN
# ...                                             ...         ...       ...
# 25954                                           NaN         NaN       NaN
# 25959  Slack Communities (ods.ai, kagglenoobs, etc)         NaN       NaN
# 25965                                           NaN         NaN       NaN
# 25966                                           NaN         NaN       NaN
# 25968  Slack Communities (ods.ai, kagglenoobs, etc)         NaN       NaN
#
# [2166 rows x 86 columns]>

# %%
df_paises = df_analista_sinOther.stb.freq(['q3_pais'])[:21]

# %%
df_paises2= df_paises.drop(df_paises.index[10:20], axis = 0)

# %%
d4 = df_analista_sinOther.stb.freq(['q3_pais']) #2166 personas encuestadas
d4['q3_pais'].unique() #63 países + 1 'i do not wish to blabla my location'
# Out:
# array(['India', 'United States of America', 'Nigeria', 'China', 'Egypt',
#        'Russia', 'Brazil',
#        'United Kingdom of Great Britain and Northern Ireland', 'Japan',
#        'Indonesia', 'Pakistan', 'Australia', 'Kenya', 'Canada', 'Germany',
#        'Taiwan', 'South Korea', 'Mexico', 'France', 'Colombia', 'Spain',
#        'Turkey', 'Poland', 'Bangladesh', 'Argentina', 'Ukraine', 'Peru',
#        'Viet Nam', 'Singapore', 'Thailand', 'Philippines', 'Italy',
#        'Ghana', 'Netherlands', 'Israel', 'Saudi Arabia', 'Malaysia',
#        'Greece', 'Hong Kong (S.A.R.)', 'United Arab Emirates',
#        'South Africa', 'Portugal', 'Iran, Islamic Republic of...',
#        'Chile', 'Sweden', 'Ecuador', 'Morocco', 'Czech Republic',
#        'Belgium', 'Sri Lanka', 'Nepal', 'Ireland',
#        'I do not wish to disclose my location', 'Belarus', 'Tunisia',
#        'Switzerland', 'Kazakhstan', 'Iraq', 'Uganda', 'Romania',
#        'Austria', 'Norway', 'Ethiopia', 'Denmark'], dtype=object)

# %%
df['q3_pais_new'] = df['q3_pais'].replace({
'India': 'India', 
'Indonesia':'Other', 
'Pakistan':'Pakistan', 
'Mexico':'Other', 
'Russia':'Russia', 
'Turkey':'Turkey',
'Australia':'Other',
'Nigeria':'Nigeria', 
'Greece':'Other', 
'Belgium':'Other', 
'Japan': 'Japan', 
'Egypt':'Other',
'Singapore':'Other', 
'Brazil':'Brazil', 
'Poland':'Other', 
'China':'Other',
'Iran, Islamic Republic of...':'Other',
'United States of America': 'USA',
'Italy':'Other',
'Viet Nam':'Other',
'Israel':'Other', 
'Peru':'Other',
'South Africa':'Other',
'Other':'Other',
'Spain':'Spain', 
'Bangladesh':'Other',
'United Kingdom of Great Britain and Northern Ireland':'Other', 
'France':'France',
'Switzerland':'Other', 
'Algeria':'Other', 
'Tunisia':'Other', 
'Argentina':'Other', 
'Sweden':'Other',
'Colombia':'Other', 
'I do not wish to disclose my location':'Other', 
'Canada':'Other',
'Chile':'Other', 
'Netherlands':'Other', 
'Ukraine':'Other', 
'Saudi Arabia':'Other', 
'Romania':'Other',
'Morocco':'Other', 
'Austria':'Other', 
'Taiwan':'Other', 
'Kenya':'Other', 
'Belarus':'Other', 
'Ireland':'Other',
'Portugal':'Other', 
'Hong Kong (S.A.R.)':'Other', 
'Denmark':'Other', 
'Germany':'Other',
'South Korea':'Other', 
'Philippines':'Other', 
'Sri Lanka':'Other', 
'United Arab Emirates':'Other',
'Uganda':'Other', 
'Ghana':'Other', 
'Malaysia':'Other', 
'Thailand':'Other', 
'Nepal':'Other', 
'Kazakhstan':'Other',
'Ethiopia':'Other', 
'Iraq':'Other', 
'Ecuador':'Other', 
'Norway':'Other', 
'Czech Republic':'Other'})

# %%
df.head(2)
# Out:
#   q1_edad q2_genero    q3_pais       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech q8_l_recomendado  \
# 0  5-10 years           Python
# 1   20+ years           Python
#
#                                  q11_tipo_plataforma    q25_salario  \
# 0                                           A laptop  25,000-29,999
# 1  A cloud computing platform (AWS, Azure, GCP, h...  60,000-69,999
#
#   q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# 0      $100-$999                 NaN              NaN
# 1      $0 ($USD)                 NaN              NaN
#
#                                   q41_h_process_data     q7_l_utilizados  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                            q14_h_viz         q10_part_1  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                        Matplotlib    Kaggle Notebooks
#
#         q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# 0  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#   q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
#
#   q10_part_14 q10_part_15 q10_part_16 q10_other  \
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
#
#                                           q18_part_1 q18_part_2 q18_part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1 q27_a_part_2  \
# 0        NaN        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN        NaN       NaN          NaN          NaN
#
#                     q27_a_part_3 q27_a_part_4 q27_a_part_5 q27_a_part_6  \
# 0   Google Cloud Platform (GCP)           NaN          NaN          NaN
# 1                            NaN          NaN          NaN          NaN
#
#   q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10 q27_a_part_11  \
# 0          NaN          NaN          NaN           NaN           NaN
# 1          NaN          NaN          NaN           NaN           NaN
#
#   q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4 q39_part_5  \
# 0         NaN        NaN        NaN        NaN    GitHub         NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
#
#   q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other q40_part_1 q40_part_2  \
# 0    Kaggle         NaN        NaN        NaN       NaN   Coursera        edX
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
#
#              q40_part_3 q40_part_4 q40_part_5 q40_part_6 q40_part_7  \
# 0  Kaggle Learn Courses   DataCamp        NaN    Udacity      Udemy
# 1  Kaggle Learn Courses        NaN        NaN        NaN        NaN
#
#   q40_part_8                                         q40_part_9  \
# 0        NaN                                                NaN
# 1        NaN  Cloud-certification programs (direct from AWS,...
#
#                                          q40_part_10 q40_part_11 q40_other  \
# 0                                                NaN         NaN       NaN
# 1  University Courses (resulting in a university ...         NaN       NaN
#
#   q42_part_1                                         q42_part_2 q42_part_3  \
# 0        NaN  Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 1        NaN                                                NaN        NaN
#
#                         q42_part_4 q42_part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
#
#                                           q42_part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
#
#                                           q42_part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
#
#                                           q42_part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
#
#                                           q42_part_9 q42_part_10 q42_part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   q42_other q3_pais_new
# 0       NaN       India
# 1       NaN       Other

# %%
df['q2_genero_new'] = df['q2_genero'].replace({
'Man': 'Man', 
'Woman': 'Woman', 
'Prefer to self-describe': 'Others', 
'Nonbinary': 'Others', 
'Prefer not to say': 'Others'})

# %%
df['q1_edad_new'] = df['q1_edad'].replace({
'50-54': '50-59', 
'22-24': '22-29', 
'25-29': '22-29',
'18-21': '<22',
'30-34': '30-39', 
'40-44': '40-49',
'45-49' : '40-49',
'35-39': '30-39',
'70+':'70+',
'55-59': '50-59',
'60-69':'60-69'})

# %% [markdown]
# # -¿Qué habilidades y herramientas se utilizan más? (q33, q32)
# ### herramientas, el perfil del data analyst
# - (estudio de mercado a quien enfocar)
# - (Qué herramientas son las más demandadas).

# %% [markdown]
# - Q7 = l_utilizando
# - Q8 = l_recomendado
# - Q9 = adi (ambientes de desarrollo integrado)
# - Q11 = plataformas
# - Q14 = visualizacion
# - Q26 = presupuesto_ml_cc
# - Q32-A = big_products
# - Q33 = big_products_used
# - Q41 = tool_ppal
# ---------------------------------------------------------------------
#     - Q10= Notebook que utilizas normalmente: 17 opciones
#     - Q27= q27-A:Que plataformas de cloud computing utilizas regularmente: 12 opciones...
#     - q28: Que plataforma de cloud tienes la mejor experiencia para desarrollar : 13 opciones -- fuera
#     - q29-A : Utilizas normalmente algunos de los productos de cloud computing: 5 opciones --fuera
#     - q30-A: Usas normalmente de alguna data storage: 8 opciones --fuera
#     - q31-A: Utilizas regularmente alguno de los producto de managed machine learning --fuera
#     - q32-A: Producto big data que utilizas regularmente.: 21 opciones --fuera
#     - q33 :Producto de big data que utilizas regularmente solo las personas que respondieron mas de una opcion en la q32-a: 21 opciones
#     - q34-a: Uso regular de herramientas de inteligencia de negocios: 17 opciones -- fuera
#     - q35: Cuales son las que más, Relacionada con la q34-a si tienes mas de un opción en la 34 : 17 opciones.
#     - q36-a : Utiliza alguna herramienta de automatización de machine learning : 8 opciones --fuera
#     - q37-a: Cuales herramientas: Relacionada con la 36-a solo las que responden SI: 8 opciones --fuera
#     - q38-a: Tiene herramientas para controlar los experimentos de manage machine learning : 12 opciones --fuera
#     - q39 : Donde compartes tus análisis de datos y aplicaciones de machine learning : 10 opciones
#     - q40: En que plataformas iniciaste tu formación de análisis de datos: 12 opciones.
#     - q41: Cual es la herramienta principal que utilizas en el trabajo o escuela para procesar datos: 6 opciones
#     - q42: Cual es tu red social favorita relacionada con el data science : 12 opciones

# %%
plt.figure(figsize =(10,7))
fig = sns.histplot(x=df['q5_ocupacion'], data = df,palette = 'Set2', hue = 'q2_genero_new',kde=True)
fig.set_title('Histograma de la ocupación segun el género')
plt.xticks(rotation=90)
plt.xlabel('Ocupación')
plt.ylabel('Número de personas')
plt.savefig("graficas/30-pregunta3-ocupacion-genero.png")
plt.show()

# %%
def graficar_countplot (df,lista):
    df_lista = df[lista]
    fig, axes = plt.subplots(1, len(lista), figsize=(25,6))
    for ax in fig.axes:
        ax.tick_params(labelrotation=90)
    for i in range(len(df_lista.columns)):
        sns.countplot(x = df_lista.columns[i], data = df, ax=axes[i],palette = 'Set2', hue="q2_genero_new");
    return plt.show();

# %%
df.columns
# Out:
# Index(['q1_edad', 'q2_genero', 'q3_pais', 'q4_educacion', 'q5_ocupacion',
#        'q6_exp_tech', 'q8_l_recomendado', 'q11_tipo_plataforma', 'q25_salario',
#        'q26_ppto_ml_cc', 'q33_bigdata_product', 'q35_h_i_negocios',
#        'q41_h_process_data', 'q7_l_utilizados', 'q9_adi', 'q14_h_viz',
#        'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
#        'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
#        'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
#        'q10_part_15', 'q10_part_16', 'q10_other', 'q18_part_1', 'q18_part_2',
#        'q18_part_3', 'q18_part_4', 'q18_part_5', 'q18_part_6', 'q18_other',
#        'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
#        'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
#        'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',
#        'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
#        'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other',
#        'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
#        'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
#        'q40_part_11', 'q40_other', 'q42_part_1', 'q42_part_2', 'q42_part_3',
#        'q42_part_4', 'q42_part_5', 'q42_part_6', 'q42_part_7', 'q42_part_8',
#        'q42_part_9', 'q42_part_10', 'q42_part_11', 'q42_other', 'q3_pais_new',
#        'q2_genero_new', 'q1_edad_new'],
#       dtype='object')

# %%
col1 = ['q3_pais', 'q4_educacion', 'q5_ocupacion']

# %%
col2 = ['q6_exp_tech', 'q8_l_recomendado', 'q11_tipo_plataforma', 'q25_salario']

# %%
col3 = ['q26_ppto_ml_cc', 'q33_bigdata_product', 'q35_h_i_negocios']

# %%
col4= ['q41_h_process_data', 'q7_l_utilizados']

# %%
col5= ['q9_adi', 'q14_h_viz']

# %%
graficar_countplot(df,col1)

# %%
graficar_countplot(df,col2)

# %%
# graficar_countplot(df,col3)

# %%
# graficar_countplot(df,col4)

# %%
graficar_countplot(df,col5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [144], line 1
# ----> 1 graficar_countplot(df,col5)
#
# Cell In [133], line 8, in graficar_countplot(df, lista)
#       6 for i in range(len(df_lista.columns)):
#       7     sns.countplot(x = df_lista.columns[i], data = df, ax=axes[i],palette = 'Set2', hue="q2_genero_new");
# ----> 8 return plt.show()
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:378, in show(*args, **kwargs)
#     334 """
#     335 Display all open figures.
#     336
#    (...)
#     375 explicitly there.
#     376 """
#     377 _warn_if_gui_out_of_main_thread()
# --> 378 return _backend_mod.show(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~/.local/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:2234, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2232 if bbox_inches:
#    2233     if bbox_inches == "tight":
# -> 2234         bbox_inches = self.figure.get_tightbbox(
#    2235             renderer, bbox_extra_artists=bbox_extra_artists)
#    2236         if pad_inches is None:
#    2237             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:1639, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1636     artists = bbox_extra_artists
#    1638 for a in artists:
# -> 1639     bbox = a.get_tightbbox(renderer)
#    1640     if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1641         bb.append(bbox)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1091, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1088 self._update_label_position(renderer)
#    1090 # go back to just this axis's tick labels
# -> 1091 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1092             ticks_to_draw, renderer)
#    1094 self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#    1095 self.offsetText.set_text(self.major.formatter.get_offset())
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1068, in Axis._get_tick_bboxes(self, ticks, renderer)
#    1066 def _get_tick_bboxes(self, ticks, renderer):
#    1067     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1068     return ([tick.label1.get_window_extent(renderer)
#    1069              for tick in ticks if tick.label1.get_visible()],
#    1070             [tick.label2.get_window_extent(renderer)
#    1071              for tick in ticks if tick.label2.get_visible()])
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1068, in <listcomp>(.0)
#    1066 def _get_tick_bboxes(self, ticks, renderer):
#    1067     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1068     return ([tick.label1.get_window_extent(renderer)
#    1069              for tick in ticks if tick.label1.get_visible()],
#    1070             [tick.label2.get_window_extent(renderer)
#    1071              for tick in ticks if tick.label2.get_visible()])
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py:903, in Text.get_window_extent(self, renderer, dpi)
#     900     raise RuntimeError('Cannot get window extent w/o renderer')
#     902 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 903     bbox, info, descent = self._get_layout(self._renderer)
#     904     x, y = self.get_unitless_position()
#     905     x, y = self.get_transform().transform((x, y))
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py:306, in Text._get_layout(self, renderer)
#     303 ys = []
#     305 # Full vertical extent of font, including ascenders and descenders:
# --> 306 _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     307     "lp", self._fontproperties,
#     308     ismath="TeX" if self.get_usetex() else False)
#     309 min_dy = (lp_h - lp_d) * self._linespacing
#     311 for i, line in enumerate(lines):
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     238 flags = get_hinting_flag()
#     239 font = self._get_agg_font(prop)
# --> 240 font.set_text(s, 0.0, flags=flags)
#     241 w, h = font.get_width_height()  # width and height of unrotated string
#     242 d = font.get_descent()
#
# KeyboardInterrupt:

# %% [markdown]
# # Pregunta 3

# %%
df2 = pd.read_csv("../data/7.dataframe_limpio.csv", index_col = 0)

# Se hace esto para resetear los índices
df2.reset_index(drop=True , inplace=True)
df2.head(2)
# Out:
#   q1_edad q2_genero    q3_pais       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech     q7_l_utilizados q8_l_recomendado  \
# 0  5-10 years           Python, R           Python
# 1   20+ years   SQL, C, C++, Java           Python
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                                            q14_h_viz  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q33_bigdata_product                                 q41_h_process_data  \
# 0             Unknown  Local development environments (RStudio, Jupyt...
# 1             Unknown    Advanced statistical software (SPSS, SAS, etc.)
#
#   q1_edad_new q2_genero_new q3_pais_new   q4_educacion_new  \
# 0       50-59           Man       India  Bachelor’s degree
# 1       50-59           Man       Other    Master’s degree
#
#           q5_ocupacion_new  q25_salario_new
# 0                    Other          27499.5
# 1  Program/Project Manager          64999.5

# %% [markdown]
# - Q7 = l_utilizando
# - Q8 = l_recomendado
# - Q9 = adi (ambientes de desarrollo integrado)
# - Q11 = plataformas
# - Q14 = visualizacion
# - Q26 = presupuesto_ml_cc
# -  Q32-A = big_products
# - Q33 = big_products_used
# - Q41 = tool_ppal

# %% [markdown]
# ## **Primero el código para el dataframe general**

# %%
def separar(df,col,col2):
    df[col2] = df[col].str.split(",")
    x = df[col2].tolist()

    set1 = set() #Creamos un set para que no salgan los contenidos repetidos

    for lista in x:
        try:
            for herramienta in lista:
                herramienta = herramienta.strip()
                set1.add(herramienta)
        except:
            pass
    lista_columnas_nuevas = list(set1)

    return lista_columnas_nuevas

# %%
lista_lutilizados = separar(df2,'q7_l_utilizados','q7_l_utilizados_new')

# %%
lista_lutilizados
# Out:
# ['SQL',
#  'MATLAB',
#  'Python',
#  'Javascript',
#  'None',
#  'C++',
#  'Other',
#  'Bash',
#  'Java',
#  'C',
#  'Swift',
#  'R',
#  'Julia']

# %%
for i in lista_lutilizados: # recibe como parámero la lista resultado de la función 1. separar
    try:
        df2[i] = df2['q7_l_utilizados'].str.contains(i)
    except: 
        df2[i] = "True"

# %%
def crear_df(df,df_nuevo): # La función recibe el nombre del dataframe sobre el que trabajamos y en string otro nombre para una variable dataframe

    df_nuevo = df.melt(value_vars = df.columns)
    df_nuevo = df_nuevo[df_nuevo['value']==True].reset_index()
    df_agrup = df_nuevo.groupby(['variable'])['value'].count().reset_index()
    df_ordenado = df_agrup.sort_values('value', ascending = False)
    df_def = df_ordenado.drop_duplicates('value', keep = 'last')

    return df_def

# %%
df_lutilizado =  crear_df(df2,"df_lutilizado")
df_lutilizado
# Out:
#       variable  value
# 8       Python  22886
# 10         SQL  10756
# 1            C   7458
# 2         Java   7316
# 9            R   5334
# 3   Javascript   4331
# 5       MATLAB   2934
# 7        Other   2575
# 0         Bash   2216
# 6         None    318
# 4        Julia    305
# 11       Swift    242

# %% [markdown]
# ## **Ahora para el de analistas**

# %%
for i in lista_lutilizados: # recibe como parámero la lista resultado de la función 1. separar
    try:
        df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
    except: 
        df_analista[i] = "True"
# Out:
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = "True"
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)
# /tmp/ipykernel_1166/1242895818.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analista[i] = df_analista['q7_l_utilizados'].str.contains(i)

# %%
df_lutilizado_analista =  crear_df(df_analista,"df_lutilizado_analista")
df_lutilizado_analista
# Out:
#       variable  value
# 8       Python   1804
# 10         SQL   1399
# 9            R    715
# 2         Java    358
# 1            C    280
# 3   Javascript    229
# 7        Other    213
# 5       MATLAB    177
# 0         Bash    102
# 6         None     32
# 11       Swift     13

# %%
plt.figure(figsize= (8,5))
sns.barplot(x = 'value', y= 'variable' , 
            data=df_lutilizado_analista,
            palette = 'Set2')
plt.title('Lenguajes más utilizados')
plt.xlabel('Número de personas') # definir el nombre del eje X
#plt.ylabel(" "); # definir el nombre del eje Y
plt.show();

# %%
df_analista.columns
# Out:
# Index(['q1_edad', 'q2_genero', 'q3_pais', 'q4_educacion', 'q5_ocupacion',
#        'q6_exp_tech', 'q8_l_recomendado', 'q11_tipo_plataforma', 'q25_salario',
#        'q26_ppto_ml_cc', 'q33_bigdata_product', 'q35_h_i_negocios',
#        'q41_h_process_data', 'q7_l_utilizados', 'q9_adi', 'q14_h_viz',
#        'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
#        'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
#        'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
#        'q10_part_15', 'q10_part_16', 'q10_other', 'q18_part_1', 'q18_part_2',
#        'q18_part_3', 'q18_part_4', 'q18_part_5', 'q18_part_6', 'q18_other',
#        'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
#        'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
#        'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',
#        'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
#        'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other',
#        'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
#        'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
#        'q40_part_11', 'q40_other', 'q42_part_1', 'q42_part_2', 'q42_part_3',
#        'q42_part_4', 'q42_part_5', 'q42_part_6', 'q42_part_7', 'q42_part_8',
#        'q42_part_9', 'q42_part_10', 'q42_part_11', 'q42_other', 'SQL',
#        'MATLAB', 'Python', 'Javascript', 'None', 'C++', 'Other', 'Bash',
#        'Java', 'C', 'Swift', 'R', 'Julia'],
#       dtype='object')

# %% [markdown]
# ## ¿Y qué lenguaje recomendarías?

# %%
df_analista['q6_exp_tech'].unique()
# Out:
# array(['20+ years', '< 1 years', '3-5 years', '1-3 years', '10-20 years',
#        '5-10 years', 'I have never written code'], dtype=object)

# %%
plt.figure(figsize= (8,5))
sns.countplot(x = 'q8_l_recomendado', 
            data=df_analista,
            palette = 'Set2',
            hue  = 'q6_exp_tech',
            hue_order = ['20+ years', '10-20 years', '5-10 years', '3-5 years', '1-3 years', '< 1 years' ])
plt.xlabel('Número de personas') 
plt.title('Lenguajes recomendados por Data Analistas')
plt.ylabel(' ') # definir el nombre del eje Y
plt.legend(title = 'Experiencia como DA', loc="upper right")
plt.show();

# %% [markdown]
# ## ¿Qué tipo de plataforma utilizas?

# %%
df_analista['q11_tipo_plataforma'].unique()
# Out:
# array(['A laptop', 'A personal computer / desktop',
#        'A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)',
#        'A deep learning workstation (NVIDIA GTX, LambdaLabs, etc)', nan,
#        'None', 'Other'], dtype=object)

# %%
plt.figure(figsize= (10,8))
sns.countplot(y = 'q11_tipo_plataforma', 
            data=df_analista,
            palette = 'Set2',
            #hue  = 'q6_exp_tech',
            order = ['A laptop', 'A personal computer / desktop', 'A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)','A deep learning workstation (NVIDIA GTX, LambdaLabs, etc)'],
            hue_order = ['20+ years', '10-20 years', '5-10 years', '3-5 years', '1-3 years', '< 1 years' ])
plt.title('Tipo de plataforma utilizada')
plt.xlabel('Número de personas') 
plt.title('Ocupación en el sector Data y nivel de educación')
plt.ylabel(' ') # definir el nombre del eje Y
#plt.legend(title = 'Experiencia como DA', loc="lower right")
plt.show();

# %% [markdown]
# ## **Big Data products que utilizan los Analistas de Datos**

# %%
df_bigdataproducts =  df_analista['q33_bigdata_product'].value_counts().reset_index()
df_bigdataproducts.head()
# Out:
#                     index  q33_bigdata_product
# 0                  MySQL                   158
# 1   Microsoft SQL Server                   119
# 2             PostgreSQL                    75
# 3  Google Cloud BigQuery                    49
# 4        Oracle Database                    47

# %%
df_bigdataproducts  =  df_analista.stb.freq(['q33_bigdata_product'], thresh = 70, other_label= 'Other').reset_index()

# %%
df_bigdataproducts.head()
# Out:
#    index     q33_bigdata_product  count    percent  cumulative_count  \
# 0      0                  MySQL     158  26.029654               158
# 1      1   Microsoft SQL Server     119  19.604613               277
# 2      2             PostgreSQL      75  12.355848               352
# 3      3  Google Cloud BigQuery      49   8.072488               401
# 4      4                   Other    206  33.937397               607
#
#    cumulative_percent
# 0           26.029654
# 1           45.634267
# 2           57.990115
# 3           66.062603
# 4          100.000000

# %%
df_bigdataproducts['percent'].dtypes
# Out:
# dtype('float64')

# %%
fig1, ax1 = plt.subplots(figsize = (10,8))
ax1.pie(df_bigdataproducts['percent'],labels = df_bigdataproducts["q33_bigdata_product"],colors = ['pink','grey','turquoise','green','orange'], autopct='%.0f%%')

plt.title('Big Data products más utilizados')
plt.xlabel('Porcentaje de uso dentro de nuestra muestra') 
plt.ylabel(' ') # definir el nombre del eje Y
#plt.legend(title = 'Experiencia como DA', loc="lower right")
plt.show()

# %% [markdown]
# ## Ambientes de desarrollo integrados

# %%
'q9_adi', 'q14_h_viz',
# Out:
# ('q9_adi', 'q14_h_viz')

# %%
df_ambientes =  df_analista.stb.freq(['q9_adi'])[:6].reset_index()

# %%
df2['q9_adi'].value_counts()
# Out:
# Jupyter Notebook                                                                                                                   3377
# Visual Studio Code (VSCode) ,Jupyter Notebook                                                                                      1411
# Visual Studio Code (VSCode)                                                                                                         939
# PyCharm ,Jupyter Notebook                                                                                                           820
# Visual Studio Code (VSCode) ,PyCharm ,Jupyter Notebook                                                                              554
#                                                                                                                                    ...
# RStudio ,Visual Studio , Spyder, Vim / Emacs,Jupyter Notebook                                                                         1
# Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,Visual Studio Code (VSCode) , Vim / Emacs,MATLAB ,Jupyter Notebook       1
# Jupyter (JupyterLab, Jupyter Notebooks, etc) ,Visual Studio ,PyCharm , Spyder, Notepad++                                              1
# RStudio ,Visual Studio , Notepad++, Vim / Emacs                                                                                       1
# RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Notepad++, Vim / Emacs                                                          1
# Name: q9_adi, Length: 1330, dtype: int64

# %%
df2['q9_adi'].unique()
# Out:
# array([' Vim / Emacs', ' Notepad++,Jupyter Notebook',
#        'PyCharm ,Jupyter Notebook, Other', ...,
#        'Visual Studio ,Visual Studio Code (VSCode) , Notepad++, Vim / Emacs,MATLAB ,Jupyter Notebook',
#        'RStudio ,Visual Studio ,PyCharm , Spyder',
#        'RStudio ,Visual Studio ,Visual Studio Code (VSCode) , Notepad++, Vim / Emacs'],
#       dtype=object)

# %%
df_ambientes.head()
# Out:
#    index                                         q9_adi  count    percent  \
# 0      0                               Jupyter Notebook    268  12.436195
# 1      1  Visual Studio Code (VSCode) ,Jupyter Notebook     95   4.408353
# 2      2                                       RStudio      89   4.129930
# 3      3                      RStudio ,Jupyter Notebook     77   3.573086
# 4      4                      PyCharm ,Jupyter Notebook     63   2.923434
#
#    cumulative_count  cumulative_percent
# 0               268           12.436195
# 1               363           16.844548
# 2               452           20.974478
# 3               529           24.547564
# 4               592           27.470998

# %%
def separar(df,col,col2):
    df[col2] = df[col].str.split(",")
    x = df[col2].tolist()

    set1 = set() #Creamos un set para que no salgan los contenidos repetidos

    for lista in x:
        try:
            for herramienta in lista:
                herramienta = herramienta.strip()
                set1.add(herramienta)
        except:
            pass
    lista_columnas_nuevas = list(set1)

    return lista_columnas_nuevas

# %%
ambientes = separar(df2,'q9_adi','q9_adi_new')

# %%
import re

# %%
for i in ambientes: # recibe como parámero la lista resultado de la función 1. separar
    try:
        df2[i] = df2['q9_adi'].str.contains(i)
    except:
        df2[i] = df2['q9_adi'].str.contains(re.escape('Notepad++'), i)
        print (i)
# Out:
# Jupyter (JupyterLab
# Notepad++
# etc)
# /tmp/ipykernel_1166/1329820702.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df2[i] = df2['q9_adi'].str.contains(i)

# %%
df2.head(5)
# Out:
#   q1_edad q2_genero    q3_pais       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
# 2   22-24       Man   Pakistan    Master’s degree        Software Engineer
# 3   45-49       Man     Mexico    Doctoral degree       Research Scientist
# 4   45-49       Man      India    Doctoral degree                    Other
#
#   q6_exp_tech     q7_l_utilizados q8_l_recomendado  \
# 0  5-10 years           Python, R           Python
# 1   20+ years   SQL, C, C++, Java           Python
# 2   1-3 years   Python, C++, Java           Python
# 3   20+ years              Python           Python
# 4   < 1 years   Python, C, MATLAB           Python
#
#                              q9_adi  \
# 0                       Vim / Emacs
# 1        Notepad++,Jupyter Notebook
# 2  PyCharm ,Jupyter Notebook, Other
# 3           Spyder,Jupyter Notebook
# 4   Spyder,MATLAB ,Jupyter Notebook
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
# 2                                           A laptop
# 3  A cloud computing platform (AWS, Azure, GCP, h...
# 4  A cloud computing platform (AWS, Azure, GCP, h...
#
#                                            q14_h_viz  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
# 2                                        Matplotlib
# 3                                        Matplotlib
# 4             Matplotlib ,Seaborn ,Ggplot / ggplot2
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
# 2        Academics/Education  1000-9,999 employees          0         $0-999
# 3        Academics/Education  1000-9,999 employees          0  30,000-39,999
# 4        Academics/Education      50-249 employees        5-9  30,000-39,999
#
#   q33_bigdata_product                                 q41_h_process_data  \
# 0             Unknown  Local development environments (RStudio, Jupyt...
# 1             Unknown    Advanced statistical software (SPSS, SAS, etc.)
# 2              MySQL   Basic statistical software (Microsoft Excel, G...
# 3             Unknown  Local development environments (RStudio, Jupyt...
# 4             Unknown  Local development environments (RStudio, Jupyt...
#
#   q1_edad_new q2_genero_new q3_pais_new   q4_educacion_new  \
# 0       50-59           Man       India  Bachelor’s degree
# 1       50-59           Man       Other    Master’s degree
# 2       22-29           Man    Pakistan    Master’s degree
# 3       40-49           Man       Other    Doctoral degree
# 4       40-49           Man       India    Doctoral degree
#
#           q5_ocupacion_new  q25_salario_new      q7_l_utilizados_new    SQL  \
# 0                    Other          27499.5             [Python,  R]  False
# 1  Program/Project Manager          64999.5  [ SQL,  C,  C++,  Java]   True
# 2        Software Engineer            499.5    [Python,  C++,  Java]  False
# 3       Research Scientist          34999.5                 [Python]  False
# 4                    Other          34999.5    [Python,  C,  MATLAB]  False
#
#    MATLAB  Python  Javascript   None   C++  Other   Bash   Java      C  Swift  \
# 0   False    True       False  False  True  False  False  False  False  False
# 1   False   False       False  False  True  False  False   True   True  False
# 2   False    True       False  False  True   True  False   True   True  False
# 3   False    True       False  False  True  False  False  False  False  False
# 4    True    True       False  False  True  False  False  False   True  False
#
#        R  Julia                            q9_adi_new  Spyder  \
# 0   True  False                        [ Vim / Emacs]   False
# 1  False  False        [ Notepad++, Jupyter Notebook]   False
# 2  False  False  [PyCharm , Jupyter Notebook,  Other]   False
# 3  False  False           [ Spyder, Jupyter Notebook]    True
# 4  False  False  [ Spyder, MATLAB , Jupyter Notebook]    True
#
#    Jupyter (JupyterLab  Jupyter Notebooks  Notepad++  Vim / Emacs   etc)  \
# 0                False              False      False         True  False
# 1                 True              False       True        False   True
# 2                False              False      False        False  False
# 3                False              False      False        False  False
# 4                False              False      False        False  False
#
#    Visual Studio  Sublime Text  PyCharm  RStudio  Visual Studio Code (VSCode)  \
# 0          False         False    False    False                        False
# 1          False         False    False    False                        False
# 2          False         False     True    False                        False
# 3          False         False    False    False                        False
# 4          False         False    False    False                        False
#
#    Jupyter Notebook
# 0             False
# 1              True
# 2              True
# 3              True
# 4              True

# %%
df2.columns
# Out:
# Index(['q1_edad', 'q2_genero', 'q3_pais', 'q4_educacion', 'q5_ocupacion',
#        'q6_exp_tech', 'q7_l_utilizados', 'q8_l_recomendado', 'q9_adi',
#        'q11_tipo_plataforma', 'q14_h_viz', 'q20_i_actual', 'q21_tamanio_cia',
#        'q22_da_cia', 'q25_salario', 'q33_bigdata_product',
#        'q41_h_process_data', 'q1_edad_new', 'q2_genero_new', 'q3_pais_new',
#        'q4_educacion_new', 'q5_ocupacion_new', 'q25_salario_new',
#        'q7_l_utilizados_new', 'SQL', 'MATLAB', 'Python', 'Javascript', 'None',
#        'C++', 'Other', 'Bash', 'Java', 'C', 'Swift', 'R', 'Julia',
#        'q9_adi_new', 'Spyder', 'Jupyter (JupyterLab', 'Jupyter Notebooks',
#        'Notepad++', 'Vim / Emacs', 'etc)', 'Visual Studio', 'Sublime Text',
#        'PyCharm', 'RStudio', 'Visual Studio Code (VSCode)', 'Jupyter Notebook',
#        'q14_h_viz_new'],
#       dtype='object')

# %%
df_q9 = df2[['Spyder', 'Jupyter (JupyterLab', 'Jupyter Notebooks',
       'Notepad++', 'Vim / Emacs', 'etc)', 'Visual Studio', 'Sublime Text',
       'PyCharm', 'RStudio', 'Visual Studio Code (VSCode)', 'Jupyter Notebook']]

# %%
def crear_df(df,df_nuevo): # La función recibe el nombre del dataframe sobre el que trabajamos y en string otro nombre para una variable dataframe

    df_nuevo = df.melt(value_vars = df.columns)
    df_nuevo = df_nuevo[df_nuevo['value']==True].reset_index()
    df_agrup = df_nuevo.groupby(['variable'])['value'].count().reset_index()
    df_ordenado = df_agrup.sort_values('value', ascending = False)
    df_def = df_ordenado.drop_duplicates('value', keep = 'last')

    return df_def

# %%
df3 = crear_df(df_q9,'df3')

# %%
df3.head(5)
# Out:
#             variable  value
# 1   Jupyter Notebook  18899
# 9      Visual Studio  12278
# 4            PyCharm   7466
# 2  Jupyter Notebooks   5488
# 5            RStudio   4771

# %%
plt.figure(figsize = (8,5))
sns.barplot(data = df3 , x = "value",y= 'variable', palette = 'Set2')


plt.title('Ambientes de Desarrollo Integrados más utilizados')
plt.xlabel('Número de personas ') 
plt.ylabel('Ambientes') # definir el nombre del eje Y

#plt.legend(title = 'Experiencia como DA', loc="lower right")
plt.show()

# %% [markdown]
# ## **Herramientas de visualización más utilizadas**
#
# 'q14_h_viz'

# %%
df = pd.read_csv("../data/7.dataframe_limpio.csv", index_col=0)
df.head(2)
# Out:
#   q1_edad q2_genero    q3_pais       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech     q7_l_utilizados q8_l_recomendado  \
# 0  5-10 years           Python, R           Python
# 1   20+ years   SQL, C, C++, Java           Python
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                                            q14_h_viz  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q33_bigdata_product                                 q41_h_process_data  \
# 0             Unknown  Local development environments (RStudio, Jupyt...
# 1             Unknown    Advanced statistical software (SPSS, SAS, etc.)
#
#   q1_edad_new q2_genero_new q3_pais_new   q4_educacion_new  \
# 0       50-59           Man       India  Bachelor’s degree
# 1       50-59           Man       Other    Master’s degree
#
#           q5_ocupacion_new  q25_salario_new
# 0                    Other          27499.5
# 1  Program/Project Manager          64999.5

# %%
df_analista = df[df['q5_ocupacion'] == 'Data Analyst']

# %%
df["q14_h_viz"].value_counts()
# Out:
#  Matplotlib ,Seaborn                                                                   7698
#  Matplotlib                                                                            3764
#  None                                                                                  3475
#  Matplotlib ,Seaborn ,Plotly / Plotly Express                                          2096
#  Matplotlib ,Seaborn ,Ggplot / ggplot2                                                  968
#                                                                                        ...
#  Matplotlib ,Bokeh ,Leaflet / Folium                                                      1
#  Matplotlib ,Plotly / Plotly Express ,D3 js ,Geoplotlib                                   1
# Seaborn ,Plotly / Plotly Express ,Ggplot / ggplot2 ,Shiny ,D3 js ,Leaflet / Folium        1
#  Matplotlib ,D3 js ,Bokeh ,Geoplotlib                                                     1
# Ggplot / ggplot2 ,D3 js , Other                                                           1
# Name: q14_h_viz, Length: 467, dtype: int64

# %%
# Creamos una función que separe las distintas opciones por columna y nos devuelva una lista con las distintas opciones.

def separar(df,col,col2):
    df[col2] = df[col].str.split(",")
    x = df[col2].tolist()

    set1 = set() #Creamos un set para que no salgan los contenidos repetidos

    for lista in x:
        try:
            for herramienta in lista:
                herramienta = herramienta.strip()
                set1.add(herramienta)
        except:
            pass
    lista_columnas_nuevas = list(set1)

    return lista_columnas_nuevas

# %%
# Creamos la lista con las columnas que nos interesan 
lista_14 = separar(df,"q14_h_viz","q14_h_viz_new")

# %%
# Comprobamos la lista
lista_14[:10]
# Out:
# ['Matplotlib',
#  'Shiny',
#  'Altair',
#  'Ggplot / ggplot2',
#  'Bokeh',
#  'Leaflet / Folium',
#  'Plotly / Plotly Express',
#  'None',
#  'D3 js',
#  'Seaborn']

# %%
df["q14_h_viz_new"]
# Out:
# 0        [ Matplotlib , Seaborn , Ggplot / ggplot2 , Sh...
# 1                                           [ Matplotlib ]
# 2                                           [ Matplotlib ]
# 3                                           [ Matplotlib ]
# 4              [ Matplotlib , Seaborn , Ggplot / ggplot2 ]
#                                ...
# 25968                             [ Matplotlib , Seaborn ]
# 25969                                              [ None]
# 25970                             [ Matplotlib , Seaborn ]
# 25971                             [ Matplotlib , Seaborn ]
# 25972                             [ Matplotlib , Seaborn ]
# Name: q14_h_viz_new, Length: 25965, dtype: object

# %%
# Realizamos un bucle for que nos devuelva una matriz de booleanos con las opciones que han sido seleccionadas o no en cada caso.

for i in lista_14: # recibe como parámero la lista resultado de la función 1. separar
    try:
        df[i] = df["q14_h_viz"].str.contains(i)
    except:
        df[i] = df["q14_h_viz"].str.contains(re.escape("Notepad++"), i)
        print (i)

# %%
df_analista.columns
# Out:
# Index(['q1_edad', 'q2_genero', 'q3_pais', 'q4_educacion', 'q5_ocupacion',
#        'q6_exp_tech', 'q7_l_utilizados', 'q8_l_recomendado', 'q9_adi',
#        'q11_tipo_plataforma', 'q14_h_viz', 'q20_i_actual', 'q21_tamanio_cia',
#        'q22_da_cia', 'q25_salario', 'q33_bigdata_product',
#        'q41_h_process_data', 'q1_edad_new', 'q2_genero_new', 'q3_pais_new',
#        'q4_educacion_new', 'q5_ocupacion_new', 'q25_salario_new'],
#       dtype='object')

# %%
def crear_df(df,df_nuevo): # La función recibe el nombre del dataframe sobre el que trabajamos y en string otro nombre para una variable dataframe

    df_nuevo = df.melt(value_vars = df.columns)
    df_nuevo = df_nuevo[df_nuevo['value']==True].reset_index()
    df_agrup = df_nuevo.groupby(['variable'])['value'].count().reset_index()
    df_ordenado = df_agrup.sort_values('value', ascending = False)
    df_def = df_ordenado.drop_duplicates('value', keep = 'last')

    return df_def

# %%
# Se debe crear un dataframe
df_viz = crear_df(df,"df_viz")
df_viz
# Out:
#                    variable  value
# 6                Matplotlib  19594
# 10                  Seaborn  14587
# 9   Plotly / Plotly Express   5778
# 4          Ggplot / ggplot2   5100
# 7                      None   3475
# 11                    Shiny   1322
# 3                Geoplotlib   1148
# 1                     Bokeh   1050
# 2                     D3 js    978
# 8                     Other    776
# 5          Leaflet / Folium    716
# 0                    Altair    309

# %%
df_viz.columns
# Out:
# Index(['variable', 'value'], dtype='object')

# %%
# Creamoms una nueva función para gráficar con barplot el recuento de las opciones elegidas y que así sea mas visual

def graficar_barplot (df): # La función recibe el dataframe creado para graficar
    sns.barplot(data = df, y='variable', x = 'value', palette= "Set2");

# %%
graficar_barplot(df_viz)
