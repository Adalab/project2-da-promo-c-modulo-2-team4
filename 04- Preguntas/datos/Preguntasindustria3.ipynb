# %% [markdown]
# ¿Cuál industria paga mejor? Relación entre salario que gana y la industria que trabaja (Irene)
#
# 3.1. ¿Salario con género?
#
# 3.2. Crear 25_salario_new, con lo hecho por Irene.

# %%
import pandas as pd
import re
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidetable

# %%
pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
df = pd.read_csv("../data/6.dataframe_analisis.csv", index_col = 0)

# Se hace esto para resetear los índices
df.reset_index(drop=True , inplace=True)
df.head(2)
# Out:
#   q1_edad q2_genero    q3_pais       q4_educacion             q5_ocupacion  \
# 0   50-54       Man      India  Bachelor’s degree                    Other
# 1   50-54       Man  Indonesia    Master’s degree  Program/Project Manager
#
#   q6_exp_tech q8_l_recomendado  \
# 0  5-10 years           Python
# 1   20+ years           Python
#
#                                  q11_tipo_plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                 q20_i_actual       q21_tamanio_cia q22_da_cia    q25_salario  \
# 0  Manufacturing/Fabrication      50-249 employees        3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees        1-2  60,000-69,999
#
#   q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# 0      $100-$999                 NaN              NaN
# 1      $0 ($USD)                 NaN              NaN
#
#                                   q41_h_process_data     q7_l_utilizados  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                         q9_adi  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                                            q14_h_viz         q10_part_1  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                        Matplotlib    Kaggle Notebooks
#
#         q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# 0  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1  Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#   q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
#
#   q10_part_14 q10_part_15 q10_part_16 q10_other  \
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
#
#                                           q18_part_1 q18_part_2 q18_part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1 q27_a_part_2  \
# 0        NaN        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN        NaN       NaN          NaN          NaN
#
#                     q27_a_part_3 q27_a_part_4 q27_a_part_5 q27_a_part_6  \
# 0   Google Cloud Platform (GCP)           NaN          NaN          NaN
# 1                            NaN          NaN          NaN          NaN
#
#   q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10 q27_a_part_11  \
# 0          NaN          NaN          NaN           NaN           NaN
# 1          NaN          NaN          NaN           NaN           NaN
#
#   q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4 q39_part_5  \
# 0         NaN        NaN        NaN        NaN    GitHub         NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
#
#   q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other q40_part_1 q40_part_2  \
# 0    Kaggle         NaN        NaN        NaN       NaN   Coursera        edX
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
#
#              q40_part_3 q40_part_4 q40_part_5 q40_part_6 q40_part_7  \
# 0  Kaggle Learn Courses   DataCamp        NaN    Udacity      Udemy
# 1  Kaggle Learn Courses        NaN        NaN        NaN        NaN
#
#   q40_part_8                                         q40_part_9  \
# 0        NaN                                                NaN
# 1        NaN  Cloud-certification programs (direct from AWS,...
#
#                                          q40_part_10 q40_part_11 q40_other  \
# 0                                                NaN         NaN       NaN
# 1  University Courses (resulting in a university ...         NaN       NaN
#
#   q42_part_1                                         q42_part_2 q42_part_3  \
# 0        NaN  Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 1        NaN                                                NaN        NaN
#
#                         q42_part_4 q42_part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
#
#                                           q42_part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
#
#                                           q42_part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
#
#                                           q42_part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
#
#                                           q42_part_9 q42_part_10 q42_part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   q42_other
# 0       NaN
# 1       NaN

# %%
df['genero_new_q2'].value_counts()

# %%
df['genero_new_q2'] = df['q2_genero'].replace({
'Man': 'Man', 
'Woman': 'Woman', 
'Prefer to self-describe': 'Others', 
'Nonbinary': 'Others', 
'Prefer not to say': 'Others'})

# %%
df['genero_new_q2'].value_counts()
# Out:
# Man       20598
# Woman      4890
# Others      485
# Name: genero_new_q2, dtype: int64

# %%
df['genero_new_q2'].value_counts()

# %% [markdown]
# crear un df donde esta el peso que vamos a dar. Hacer un map, si es hombre ponga 10,3,1. Tras el map , hacer el método de media ponderada.
# Map opcional.
# Media ponderada por cada identidad de género.
# Filtrar por genero y hacer un dataframe, función que acceda a cada valor del salario de los hombres y le
# Decidir los pesos. Entre más nueroso, mayos pesos
#
# def media (col):
#     x*peso
#     resultado= 0
#     resultado=x*peso . Multiplicar hombre por sus pesos
#
#     dataframe con género y media ponderada.
#     bar plot

# %%
df['educacion_new_q4'] = df['q4_educacion'].replace({
'Master’s degree': 'Master’s degree', 
'Bachelor’s degree': 'Bachelor’s degree', 
'Doctoral degree': 'Doctoral degree',
'Professional doctorate': 'Professional doctorate',
'No formal education past high school': 'Others', 
'Some college/university study without earning a bachelor’s degree': 'Others', 
'I prefer not to answer': 'Others'})

# %%
df['q25_salario_limpia']= df['q25_salario'].replace({',':''}, regex=True)

# %%
def limpia_salario(salario):
    patron = "(\d+|\d+)"
    try:
        return re.findall(patron, str(salario))
    except: 
        np.nan

# %%
df['q25_salario_new'] = (df['q25_salario_limpia'].apply(limpia_salario))

# %%
df['salario1'] = df['q25_salario_new'].str.get(0)

# %%
df['salario1'] = df['salario1'].astype('Int64', errors = 'raise')

# %%
df['salario2'] = df['q25_salario_new'].str.get(1)

# %%
df['salario2'] = df['salario2'].astype('Int64', errors = 'raise')

# %%
df['media_salario'] = df[['salario1', 'salario2']].mean(axis  = 1)

# %%
df['media_salario'].head()
# Out:
# 0    27499.5
# 1    64999.5
# 2      499.5
# 3    34999.5
# 4    34999.5
# Name: media_salario, dtype: float64

# %%
df['media_salario'].dtype
# Out:
# dtype('float64')

# %%
df_analistas = df[df["q5_ocupacion"]== "Data Analyst"]

# %% [markdown]
# # ¿Qué industria paga mejor a los Data Anlalyst?

# %%
df_industria = df_analistas.groupby('q20_i_actual').mean()
df_industria.reset_index(inplace=True)
df_industria.head()
# Out:
# /tmp/ipykernel_11756/2389554831.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_industria = df_analistas.groupby('q20_i_actual').mean()
#                   q20_i_actual      salario1      salario2  media_salario
# 0          Academics/Education  15362.416107  15204.387205   16935.743289
# 1           Accounting/Finance  27490.234375      33967.75   30728.992188
# 2  Broadcasting/Communications   23877.55102  29978.591837   26928.071429
# 3         Computers/Technology  21161.157025   26941.14876   24051.152893
# 4                Energy/Mining  22431.818182  27930.818182   25181.318182

# %%
df_industria_ordenado = df_industria.sort_values('media_salario', ascending = False)

# %%
sns.barplot(y='q20_i_actual', x = 'media_salario', data= df_industria_ordenado, palette = 'Set2')


plt.show()

# %%
df_analista["q2_genero_new"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11756/1798834336.py in <module>
# ----> 1 df_analista["q2_genero_new"].value_counts()
#
# NameError: name 'df_analista' is not defined

# %% [markdown]
# # Para ver las industrias, en España, que mejor pagan:

# %%
df_españa_ind = df_analistas[df_analistas['q3_país'] == 'Spain']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802             try:
# -> 3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'q3_país'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_11756/605496617.py in <module>
# ----> 1 df_españa_ind = df_analistas[df_analistas['q3_país'] == 'Spain']
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3803             if self.columns.nlevels > 1:
#    3804                 return self._getitem_multilevel(key)
# -> 3805             indexer = self.columns.get_loc(key)
#    3806             if is_integer(indexer):
#    3807                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
# -> 3805                 raise KeyError(key) from err
#    3806             except TypeError:
#    3807                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'q3_país'

# %%
df_industria2 = df_españa_ind.groupby('q20_i_actual').mean()
df_industria2.reset_index(inplace=True)
df_industria2.head(20)
# Out:
#                              q20_i_actual  salario1      salario2  \
# 0                     Academics/Education   39625.0       47499.0
# 1                      Accounting/Finance   12000.0  15665.666667
# 2                    Computers/Technology   25000.0       29999.0
# 3                           Energy/Mining   40000.0       49999.0
# 4               Government/Public Service   45000.0       54999.0
# 5                  Medical/Pharmaceutical   45000.0       54999.0
# 6  Online Service/Internet-based Services   60000.0       69999.0
# 7                                   Other   20000.0       25499.0
# 8                            Retail/Sales   30000.0  36665.666667
# 9                 Shipping/Transportation   40000.0       49999.0
#
#    media_salario
# 0   43562.000000
# 1   13832.833333
# 2   27499.500000
# 3   44999.500000
# 4   49999.500000
# 5   49999.500000
# 6   64999.500000
# 7   22749.500000
# 8   33332.833333
# 9   44999.500000

# %%
df_industria_ordenado_esp = df_industria2.sort_values('media_salario', ascending = False)

# %%
plt.figure(figsize= (8,5))
sns.set_theme(style="whitegrid")# grid
sns.barplot(y='q20_i_actual', x = 'media_salario', data= df_industria_ordenado_esp , palette = 'Set2')


plt.show()

# %% [markdown]
# Algunas diferencias respecto al gráfico global: En España, en segundo lugar está el servicio público (En el primer gráfico en segundo lugar estaría la indsutria farmacéutica) En españa está mejor pagado comparativamente, se cobra 55 mil euros de media anual.
# Otros cambios importantes que vemos: aquí accounting finance está en último lugar, con un sueldo medio de 13800 euros. Muy por debajo  de la media global en este sector, cuya media es de 30700 euros anuales.
# En ambos gráficos vemos que destacan los trabajos relacionados con el servicio online, tanto a nivel global como en nuestro territorio es la industria que mejor paga y a donde igual podemos ir echando el ojo como futuras analistas, jejeje.

# %% [markdown]
# ¿Por qué?

# %% [markdown]
# ## ¿Y como está colocado el analista de datos respecto a otros puestos en cuánto a salario?

# %%
df_salario_ocupacion = df.groupby('q5_ocupacion').mean()

# %%
df_salario_ocupacion.reset_index(inplace=True)

# %%
df_salario_ocupacion['q5_ocupacion'].unique()
# Out:
# array(['Business Analyst', 'Currently not employed',
#        'DBA/Database Engineer', 'Data Analyst', 'Data Engineer',
#        'Data Scientist', 'Developer Relations/Advocacy',
#        'Machine Learning Engineer', 'Other', 'Product Manager',
#        'Program/Project Manager', 'Research Scientist',
#        'Software Engineer', 'Statistician', 'Student'], dtype=object)

# %%
df_salario_ocupacion = df_salario_ocupacion[(df_salario_ocupacion['q5_ocupacion'] != 'Student') & (df_salario_ocupacion['q5_ocupacion'] != 'Currently not employed') ]
df_ocu_ordenado = df_salario_ocupacion.sort_values('media_salario', ascending = False)

# %%
plt.figure(figsize= (8,5))
sns.set_theme(style="whitegrid")# grid
sns.barplot(y='q5_ocupacion', x = 'media_salario', data= df_ocu_ordenado , palette = 'Set2')


plt.show()

# %% [markdown]
# ¡Vaya! Somos los peores pagados de nuestra lista

# %% [markdown]
# ## ¿Y la brecha de género?

# %%
df_an_genero_sal = df_analistas.groupby('genero_new_q2').mean().reset_index()

# %%
df_gen_ordenado = df_an_genero_sal.sort_values('media_salario', ascending = False).reset_index()

# %%
plt.figure(figsize= (8,5))
sns.set_theme(style="whitegrid")# grid
sns.barplot(y='genero_new_q2', x = 'media_salario', data= df_gen_ordenado , palette = 'Set2')


plt.show()

# %%
df_analista["q2_genero_new"].value_counts()

# %% [markdown]
# Mira tú

# %%
df_an_genero_sal2 = df.groupby('q2_genero').mean().reset_index()
plt.figure(figsize= (8,5))
sns.set_theme(style="whitegrid")# grid
sns.barplot(y='q2_genero', x = 'media_salario', data= df_an_genero_sal2 , palette = 'Set2')


plt.show()

# %%
df_an_genero_sal2 = df.groupby('genero_').mean().reset_index()
plt.figure(figsize= (8,5))
sns.set_theme(style="whitegrid")# grid
sns.barplot(y='q2_genero', x = 'media_salario', data= df_an_genero_sal2 , palette = 'Set2')


plt.show()
