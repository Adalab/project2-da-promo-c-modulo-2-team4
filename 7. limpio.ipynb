# %%
import pandas as pd
import numpy as np
import os 
import xml.etree.ElementTree as ET
pd.options.display.max_columns = None
import re

# %%
df = pd.read_csv('data/05-data_union.csv', index_col = 0)

# %%
df_eliminar = df.drop(['tpu','hardware', 'e_actividades','Q29_A_Part_1', 'Q29_A_Part_2', 'Q29_A_Part_3', 'Q29_A_Part_4','Q29_A_OTHER', 'Q30_A_Part_1', 'Q30_A_Part_2', 'Q30_A_Part_3', 'Q30_A_Part_4', 'Q30_A_Part_5', 'Q30_A_Part_6', 'Q30_A_Part_7', 'Q30_A_OTHER'], axis = 1)

# %% [markdown]
# # Función para dividir los valores de las columnas problemáticas en nuevas columnas

# %%
df_eliminar['big_products'].unique()
# Out:
# array([' PostgreSQL ', nan, 'MySQL , MongoDB ', ...,
#        ' MongoDB , Microsoft SQL Server , Amazon Redshift ',
#        'MySQL , SQLite , MongoDB , Google Cloud BigTable ',
#        ' PostgreSQL , SQLite , MongoDB , Microsoft SQL Server , Amazon Redshift '],
#       dtype=object)

# %%
x = df_eliminar["big_product_lista"].tolist()
x[:2]
# Out:
# [[' PostgreSQL '], nan]

# %%
set1 = set()

for lista in x:
    try:
        for herramienta in lista:
            set1.add(herramienta.strip())
    except:
        pass
lista_columnas_nuevas = list(set1)
lista_columnas_nuevas
# Out:
# ['IBM Db2',
#  'Amazon DynamoDB',
#  'Google Cloud SQL',
#  'Google Cloud BigTable',
#  'Microsoft Azure Cosmos DB',
#  'SQLite',
#  'Snowflake',
#  'PostgreSQL',
#  'Amazon Redshift',
#  'Other',
#  'Microsoft Azure SQL Database',
#  'MongoDB',
#  'Microsoft SQL Server',
#  'Amazon Aurora',
#  'Google Cloud BigQuery',
#  'None',
#  'MySQL',
#  'Amazon RDS',
#  'Google Cloud Firestore',
#  'Google Cloud Spanner',
#  'Oracle Database']

# %%
for i in lista_columnas_nuevas:
    df_eliminar[i] = df_eliminar['big_products'].str.contains(i, regex = True)

# %%
df_eliminar.head(2)
# Out:
#    index  time    age gender       pais          educacion  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
#
#                  ocupacion experiencia l_recomendado  \
# 0                    Other  5-10 years        Python
# 1  Program/Project Manager   20+ years        Python
#
#                                           plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                     i_actual             e_tamanio e_analistas salario_actual  \
# 0  Manufacturing/Fabrication      50-249 employees         3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees         1-2  60,000-69,999
#
#   presupuesto_ml_cc big_products_used  \
# 0         $100-$999               NaN
# 1         $0 ($USD)               NaN
#
#                                            tool_ppal         l_utilizado  \
# ...

# %%
# def separar(col):
    # for col in lista_columnas_nuevas:
    # df_eliminar[i] = df_eliminar['big_products'].str.contains(i, regex = True)

# %%
df["Comentario"] = df["Comentario"].apply(lambda x: int(x)) #1 if str(x)=="True" else 0

# %%
import seaborn as sns

# %%
# sns.countplot(x= lista_columnas_nuevas , data= df_eliminar)

# %%
# fig = sns.countplot(data = df_eliminar, x = 'big_products', hue = 'Amazon Redshift', palette='Paired')

# %%
df_eliminar.to_csv("data/6-data-limpieza.csv")
