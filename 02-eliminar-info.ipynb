# %%
import pandas as pd
import numpy as np
import os 
import xml.etree.ElementTree as ET

# %%
pd.options.display.max_columns = None

# %%
df_csv = pd.read_csv("data/01-data_remaning_kaggle.csv")

# %%
df_csv.head(2)
# Out:
#    Unnamed: 0  index                                         Q18_Part_1  \
# 0           0      0  General purpose image/video tools (PIL, cv2, s...
# 1           1      1                                                NaN
#
#   Q18_Part_2 Q18_Part_3 Q18_Part_4 Q18_Part_5 Q18_Part_6 Q18_OTHER  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN
#
#                                           Q19_Part_1 Q19_Part_2 Q19_Part_3  \
# 0  Word embeddings/vectors (GLoVe, fastText, word...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   Q19_Part_4 Q19_Part_5 Q19_OTHER Q27_A_Part_1 Q27_A_Part_2  \
# 0        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN       NaN          NaN          NaN
#
#                     Q27_A_Part_3 Q27_A_Part_4 Q27_A_Part_5 Q27_A_Part_6  \
# ...

# %%
df_csv.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3',
#        'Q18_Part_4', 'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=214)

# %%
columnas_eliminadas_q18 = df_csv.drop(["Q18_Part_1", "Q18_Part_2",	"Q18_Part_3",	"Q18_Part_4",	"Q18_Part_5",	"Q18_Part_6",	"Q18_OTHER"], axis = 1, inplace = True)

# %%
df_csv.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Q19_Part_1', 'Q19_Part_2', 'Q19_Part_3',
#        'Q19_Part_4', 'Q19_Part_5', 'Q19_OTHER', 'Q27_A_Part_1', 'Q27_A_Part_2',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=207)

# %%
columnas_eliminadas_q19 = df_csv.drop(['Q19_Part_1', 'Q19_Part_2', 'Q19_Part_3','Q19_Part_4', 'Q19_Part_5', 'Q19_OTHER'], axis = 1, inplace = True)

# %%
columnas_eliminadas_q28 = df_csv.drop(["Q28"], axis = 1, inplace = True)

# %%
df_csv.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3',
#        'Q27_A_Part_4', 'Q27_A_Part_5', 'Q27_A_Part_6', 'Q27_A_Part_7',
#        'Q27_A_Part_8',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=200)

# %%
columnas_eliminadas_q31 = df_csv.drop(["Q31_A_Part_1","Q31_A_Part_2","Q31_A_Part_3","Q31_A_Part_4","Q31_A_Part_5","Q31_A_Part_6","Q31_A_Part_7","Q31_A_Part_8","Q31_A_Part_9","Q31_A_OTHER"], axis = 1, inplace = True)

# %%
columnas_eliminadas_q36 = df_csv.drop(["Q36_A_Part_1","Q36_A_Part_2","Q36_A_Part_3","Q36_A_Part_4","Q36_A_Part_5","Q36_A_Part_6","Q36_A_Part_7","Q36_A_OTHER"], axis = 1, inplace = True)

# %%
columnas_eliminadas_q3738 = df_csv.drop(["Q37_A_Part_1"	,"Q37_A_Part_2","Q37_A_Part_3", "Q37_A_Part_4", "Q37_A_Part_5", "Q37_A_Part_6", "Q37_A_Part_7", "Q37_A_OTHER", "Q38_A_Part_1",	"Q38_A_Part_2",	"Q38_A_Part_3", "Q38_A_Part_4", "Q38_A_Part_5", "Q38_A_Part_6",	"Q38_A_Part_7", "Q38_A_Part_8", "Q38_A_Part_9", "Q38_A_Part_10", "Q38_A_Part_11","Q38_A_OTHER"], axis = 1, inplace = True)

# %%
# columnas_eliminadas_q3738 = df_csv.drop(["Q37_A_Part_1"	,"Q37_A_Part_2","Q37_A_Part_3", "Q37_A_Part_4", "Q37_A_Part_5", "Q37_A_Part_6", "Q37_A_Part_7", "Q37_A_OTHER", "Q38_A_Part_1",	"Q38_A_Part_2",	"Q38_A_Part_3", "Q38_A_Part_4", "Q38_A_Part_5", "Q38_A_Part_6",	"Q38_A_Part_7", "Q38_A_Part_8", "Q38_A_Part_9", "Q38_A_Part_10", "Q38_A_Part_11","Q38_A_OTHER"], axis = 1, inplace = True)

# %%
df_csv.head(2)
# Out:
#    Unnamed: 0  index Q27_A_Part_1 Q27_A_Part_2                   Q27_A_Part_3  \
# 0           0      0          NaN          NaN   Google Cloud Platform (GCP)
# 1           1      1          NaN          NaN                            NaN
#
#   Q27_A_Part_4 Q27_A_Part_5 Q27_A_Part_6 Q27_A_Part_7 Q27_A_Part_8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#   Q27_A_Part_9 Q27_A_Part_10 Q27_A_Part_11 Q27_A_OTHER Q29_A_Part_1  \
# 0          NaN           NaN           NaN         NaN          NaN
# 1          NaN           NaN           NaN         NaN          NaN
#
#   Q29_A_Part_2                   Q29_A_Part_3 Q29_A_Part_4 Q29_A_OTHER  \
# 0          NaN   Google Cloud Compute Engine           NaN         NaN
# 1          NaN                            NaN          NaN         NaN
#
#   Q30_A_Part_1 Q30_A_Part_2 Q30_A_Part_3 Q30_A_Part_4  \
# ...

# %%
df_txt = pd.read_csv("data/02-data_txt_clean.csv")

# %%
df_txt.head(2)
# Out:
#    Unnamed: 0  index         Q3                 Q4                       Q5  \
# 0           0      0      India  Bachelor’s degree                    Other
# 1           1      1  Indonesia    Master’s degree  Program/Project Manager
#
#            Q6      Q8                                                Q11  \
# 0  5-10 years  Python                                           A laptop
# 1   20+ years  Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#          Q13         Q15                        Q20                   Q21  \
# 0  2-5 times  5-10 years  Manufacturing/Fabrication      50-249 employees
# 1      Never    < 1 year  Manufacturing/Fabrication  1000-9,999 employees
#
#    Q22                                                Q23            Q25  \
# 0  3-4                      No (we do not use ML methods)  25,000-29,999
# 1  1-2  We are exploring ML methods (and may one day p...  60,000-69,999
#
# ...

# %%
df_txt.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13',
#        'Q15', 'Q20', 'Q21', 'Q22', 'Q23', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41',
#        'Q7', 'Q9', 'Q12', 'Q14', 'Q16', 'Q17', 'Q24', 'Q32', 'Q34'],
#       dtype='object')

# %%
columnas_txt_eli = df_txt.drop(['Unnamed: 0','Q15', 'Q16', 'Q23','Q17','Q34'], axis = 1, inplace = True)

# %%
df_txt.columns
# Out:
# Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13', 'Q20', 'Q21',
#        'Q22', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41', 'Q7', 'Q9', 'Q12', 'Q14',
#        'Q24', 'Q32'],
#       dtype='object')

# %%
os.getcwd()
# Out:
# '/mnt/d/Ximena/Adalab/Módulo 2/project2-da-promo-c-modulo-2-team4'

# %%
df_txt.to_csv("data/03-data_txt_eliminados.csv")

# %%
df_csv.to_csv("data/03-data_csv_eliminados.csv")

# %%
df_xml = pd.read_csv("data/02-data_xml_clean.csv")

# %%
df_xml.columns
# Out:
# Index(['Unnamed: 0', 'level_0', 'index', 'time', 'age', 'gender'], dtype='object')

# %%
columnas_xml_eli = df_xml.drop(['Unnamed: 0','level_0'], axis = 1, inplace = True)

# %%
df_xml.head()
# Out:
#    index  time    age gender
# 0      0   910  50-54    Man
# 1      1   784  50-54    Man
# 2      2   924  22-24    Man
# 3      3   575  45-49    Man
# 4      4   781  45-49    Man

# %%
df_xml.to_csv("data/03-data_xml_eliminados.csv")

# %%
df_db = pd.read_csv("data/02-exported_db_data.csv")

# %%
df_db.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3',
#        'Q10_Part_4', 'Q10_Part_5', 'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8',
#        'Q10_Part_9', 'Q10_Part_10', 'Q10_Part_11', 'Q10_Part_12',
#        'Q10_Part_13', 'Q10_Part_14', 'Q10_Part_15', 'Q10_Part_16',
#        'Q10_OTHER'],
#       dtype='object')

# %%
columnas_db_eli = df_db.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df_db.to_csv("data/03-data_db_eliminados.csv")
