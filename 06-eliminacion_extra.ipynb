# %%
import pandas as pd
import numpy as np
import os 
import xml.etree.ElementTree as ET
pd.options.display.max_columns = None

# %%
df_unido = pd.read_csv('data/05-data_union.csv', index_col = 0)

# %%
df_unido.head(1)
# Out:
#    index  time    age gender   pais          educacion ocupacion experiencia  \
# 0      0   910  50-54    Man  India  Bachelor’s degree     Other  5-10 years
#
#   l_recomendado plataforma        tpu                   i_actual  \
# 0        Python   A laptop  2-5 times  Manufacturing/Fabrication
#
#           e_tamanio e_analistas salario_actual presupuesto_ml_cc  \
# 0  50-249 employees         3-4  25,000-29,999         $100-$999
#
#   big_products_used                                          tool_ppal  \
# 0               NaN  Local development environments (RStudio, Jupyt...
#
#   l_utilizado           adi            hardware  \
# 0   Python, R   Vim / Emacs  Google Cloud TPUs
#
#                                        visualizacion  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                        e_actividades  big_products kaggle_n  \
# 0   None of these activities are an important par...   PostgreSQL       NaN
#
# ...

# %%
df_unido.columns
# Out:
# Index(['index', 'time', 'age', 'gender', 'pais', 'educacion', 'ocupacion',
#        'experiencia', 'l_recomendado', 'plataforma',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=201)

# %%
columnas_extra_eliminadas1 = df_unido.drop(['tpu','hardware','Q29_A_PART_1','Q29_A_PART_2','Q29_A_PART_3','Q29_A_PART_4','Q29_A_OTHER','Q30_PART_1','Q30_A_PART_2','Q30_A_PART_2', 'Q30_A_PART_3','Q30_A_PART_4', 'Q30_A_PART_5','Q30_A_PART_6','Q30_A_PART_7','Q30_A_OTHER'] axis = 1, inplace = True )
# Out:
#   File "/tmp/ipykernel_1275/2917660709.py", line 1
#     columnas_extra_eliminadas1 = df_unido.drop(['tpu','hardware','Q29_A_PART_1','Q29_A_PART_2','Q29_A_PART_3','Q29_A_PART_4','Q29_A_OTHER','Q30_PART_1','Q30_A_PART_2','Q30_A_PART_2', 'Q30_A_PART_3','Q30_A_PART_4', 'Q30_A_PART_5','Q30_A_PART_6','Q30_A_PART_7','Q30_A_OTHER'] axis = 1, inplace = True )
#                                                                                                                                                                                                                                                                                   ^
# SyntaxError: invalid syntax
