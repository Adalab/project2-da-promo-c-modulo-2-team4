# %% [markdown]
# ## Código para columnas con contenido múltiple en celdas

# %%
import pandas as pd
import numpy as np
import os 
import xml.etree.ElementTree as ET
import seaborn as sns
import re
import matplotlib.pyplot as plt
pd.options.display.max_columns = None

# %%
df = pd.read_csv('data/05-data_union.csv', index_col = 0)

# %%
df.head(1)
# Out:
#    index  time    age gender   pais          educacion ocupacion experiencia  \
# 0      0   910  50-54    Man  India  Bachelor’s degree     Other  5-10 years
#
#   l_recomendado plataforma        tpu                   i_actual  \
# 0        Python   A laptop  2-5 times  Manufacturing/Fabrication
#
#           e_tamanio e_analistas salario_actual presupuesto_ml_cc  \
# 0  50-249 employees         3-4  25,000-29,999         $100-$999
#
#   big_products_used                                          tool_ppal  \
# 0               NaN  Local development environments (RStudio, Jupyt...
#
#   l_utilizado           adi            hardware  \
# 0   Python, R   Vim / Emacs  Google Cloud TPUs
#
#                                        visualizacion  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                        e_actividades  big_products kaggle_n  \
# 0   None of these activities are an important par...   PostgreSQL       NaN
#
# ...

# %%
df2 = df.drop(['tpu','hardware', 'e_actividades','Q29_A_Part_1', 'Q29_A_Part_2', 'Q29_A_Part_3', 'Q29_A_Part_4','Q29_A_OTHER', 'Q30_A_Part_1', 'Q30_A_Part_2', 'Q30_A_Part_3', 'Q30_A_Part_4', 'Q30_A_Part_5', 'Q30_A_Part_6', 'Q30_A_Part_7', 'Q30_A_OTHER'], axis = 1)

# %% [markdown]
# Función para separar los datos múltiples

# %%
def separar(df,col,col2):
    df[col2] = df2[col].str.split(",")
    x = df[col2].tolist()

    set1 = set() #Creamos un set para que no salgan los contenidos repetidos

    for lista in x:
        try:
            for herramienta in lista:
                herramienta = herramienta.strip()
                set1.add(herramienta)
        except:
            pass
    lista_columnas_nuevas = list(set1)

    return lista_columnas_nuevas

# %%
lista_lutilizados = separar(df2,'l_utilizado','l_utilizado2')

# %%
lista_lutilizados[:10]
# Out:
# ['Other', 'None', 'C', 'Bash', 'Java', 'Swift', 'C++', 'R', 'Julia', 'MATLAB']

# %%
for i in lista_lutilizados:
    df2[i] = df2['l_utilizado'].str.contains(i)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Untitled-1.ipynb Cell 12 in <cell line: 1>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=0'>1</a> for i in lista_lutilizados:
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=1'>2</a>     df2[i] = df2['l_utilizado'].str.contains(i)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# ...

# %%
df2.head()
# Out:
#    index  time    age gender       pais          educacion  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
# 2      2   924  22-24    Man   Pakistan    Master’s degree
# 3      3   575  45-49    Man     Mexico    Doctoral degree
# 4      4   781  45-49    Man      India    Doctoral degree
#
#                  ocupacion experiencia l_recomendado  \
# 0                    Other  5-10 years        Python
# 1  Program/Project Manager   20+ years        Python
# 2        Software Engineer   1-3 years        Python
# 3       Research Scientist   20+ years        Python
# 4                    Other   < 1 years        Python
#
#                                           plataforma  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
# 2                                           A laptop
# 3  A cloud computing platform (AWS, Azure, GCP, h...
# ...

# %%
df2['l_utilizado2'] = df2['l_utilizado'].str.split(",")
x = df['l_utilizado'].tolist()

set1 = set() #Creamos un set para que no salgan los contenidos repetidos

for lista in x:
    try:
        for herramienta in lista:
            herramienta = herramienta.strip()
            set1.add(herramienta)
    except:
        pass
lista_columnas_nuevas2 = list(set1)

# %%
for i in lista_columnas_nuevas2:
    df2[i] = df2['l_utilizado'].str.contains(i)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Untitled-1.ipynb Cell 13 in <cell line: 1>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X41sdW50aXRsZWQ%3D?line=0'>1</a> for i in lista_columnas_nuevas2:
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X41sdW50aXRsZWQ%3D?line=1'>2</a>     df2[i] = df2['l_utilizado'].str.contains(i)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# ...

# %% [markdown]
# ## Función para generar las gráficas con las columnas de booleanos

# %%
def graficar(df,df_nuevo):

    df_nuevo = df.melt(value_vars = df.columns)
    df_nuevo = df_nuevo[df_nuevo['value']==True].reset_index()
    df_agrup = df_nuevo.groupby(['variable'])['value'].count().reset_index()
    df_ordenado = df_agrup.sort_values('value', ascending = False)
    df_def = df_ordenado.drop_duplicates('value', keep = 'last')

    return df_def

# %%
graficar()
