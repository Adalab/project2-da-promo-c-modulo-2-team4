# %%
import pandas as pd
import numpy as np
import os
pd.options.display.max_columns = None

# %%
df_db= pd.read_csv("data/04-data-db-col-rename.csv", index_col=0)
df_db.head(2)
# Out:
#    Unnamed: 0  index           kaggle_n          colab_n azure_n  \
# 0           0      0                NaN  Colab Notebooks     NaN
# 1           1      1   Kaggle Notebooks  Colab Notebooks     NaN
#
#   paper_space_gradient binder_jupyter_hub code_ocean ibm_ws amazon_ssn  \
# 0                  NaN                NaN        NaN    NaN        NaN
# 1                  NaN                NaN        NaN    NaN        NaN
#
#   amazoner_n googlec_n googlec_d databricksc_n zeppelin_zn deepnote_n obs_n  \
# 0        NaN       NaN       NaN           NaN         NaN        NaN   NaN
# 1        NaN       NaN       NaN           NaN         NaN        NaN   NaN
#
#   none other
# 0  NaN   NaN
# 1  NaN   NaN

# %%
df_txt= pd.read_csv("data/04-data-txt-col-rename.csv",index_col=0 )
df_txt.head(2)
# Out:
#    Unnamed: 0  index       pais          educacion                ocupacion  \
# 0           0      0      India  Bachelor’s degree                    Other
# 1           1      1  Indonesia    Master’s degree  Program/Project Manager
#
#   experiencia l_recomendado  \
# 0  5-10 years        Python
# 1   20+ years        Python
#
#                                           plataforma        tpu  \
# 0                                           A laptop  2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#                     i_actual             e_tamanio e_analistas salario_actual  \
# 0  Manufacturing/Fabrication      50-249 employees         3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees         1-2  60,000-69,999
#
#   presupuesto_ml_cc big_products_used  \
# 0         $100-$999               NaN
# 1         $0 ($USD)               NaN
#
#                                            tool_ppal         l_utilizado  \
# ...

# %%
df_xml= pd.read_csv("data/03-data_xml_eliminados.csv", index_col=0)
df_xml.head(2)
# Out:
#    index  time    age gender
# 0      0   910  50-54    Man
# 1      1   784  50-54    Man

# %%
df_csv= pd.read_csv("data/03-data_csv_eliminados.csv",index_col=0 )
df_csv.head(2)
# Out:
#    Unnamed: 0  index Q27_A_Part_1 Q27_A_Part_2                   Q27_A_Part_3  \
# 0           0      0          NaN          NaN   Google Cloud Platform (GCP)
# 1           1      1          NaN          NaN                            NaN
#
#   Q27_A_Part_4 Q27_A_Part_5 Q27_A_Part_6 Q27_A_Part_7 Q27_A_Part_8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#   Q27_A_Part_9 Q27_A_Part_10 Q27_A_Part_11 Q27_A_OTHER Q29_A_Part_1  \
# 0          NaN           NaN           NaN         NaN          NaN
# 1          NaN           NaN           NaN         NaN          NaN
#
#   Q29_A_Part_2                   Q29_A_Part_3 Q29_A_Part_4 Q29_A_OTHER  \
# 0          NaN   Google Cloud Compute Engine           NaN         NaN
# 1          NaN                            NaN          NaN         NaN
#
#   Q30_A_Part_1 Q30_A_Part_2 Q30_A_Part_3 Q30_A_Part_4  \
# ...

# %%
df_csv.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3',
#        'Q27_A_Part_4', 'Q27_A_Part_5', 'Q27_A_Part_6', 'Q27_A_Part_7',
#        'Q27_A_Part_8',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=162)

# %%
#eliminar columnas
df_csv.drop(['Unnamed: 0'], axis= 1, inplace=True)

# %%
df_csv.head(2)
# Out:
#    index Q27_A_Part_1 Q27_A_Part_2                   Q27_A_Part_3  \
# 0      0          NaN          NaN   Google Cloud Platform (GCP)
# 1      1          NaN          NaN                            NaN
#
#   Q27_A_Part_4 Q27_A_Part_5 Q27_A_Part_6 Q27_A_Part_7 Q27_A_Part_8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#   Q27_A_Part_9 Q27_A_Part_10 Q27_A_Part_11 Q27_A_OTHER Q29_A_Part_1  \
# 0          NaN           NaN           NaN         NaN          NaN
# 1          NaN           NaN           NaN         NaN          NaN
#
#   Q29_A_Part_2                   Q29_A_Part_3 Q29_A_Part_4 Q29_A_OTHER  \
# 0          NaN   Google Cloud Compute Engine           NaN         NaN
# 1          NaN                            NaN          NaN         NaN
#
#   Q30_A_Part_1 Q30_A_Part_2 Q30_A_Part_3 Q30_A_Part_4  \
# 0          NaN          NaN          NaN          NaN
# ...

# %%
df_db.drop(['Unnamed: 0'], axis= 1, inplace=True)
df_db.columns
# Out:
# Index(['index', 'kaggle_n', 'colab_n', 'azure_n', 'paper_space_gradient',
#        'binder_jupyter_hub', 'code_ocean', 'ibm_ws', 'amazon_ssn',
#        'amazoner_n', 'googlec_n', 'googlec_d', 'databricksc_n', 'zeppelin_zn',
#        'deepnote_n', 'obs_n', 'none', 'other'],
#       dtype='object')

# %%
df_txt.drop(['Unnamed: 0'], axis= 1, inplace=True)
df_txt.columns
# Out:
# Index(['index', 'pais', 'educacion', 'ocupacion', 'experiencia',
#        'l_recomendado', 'plataforma', 'tpu', 'i_actual', 'e_tamanio',
#        'e_analistas', 'salario_actual', 'presupuesto_ml_cc',
#        'big_products_used', 'tool_ppal', 'l_utilizado', 'adi', 'hardware',
#        'visualizacion', 'e_actividades', 'big_products'],
#       dtype='object')

# %%
#unirlos

# %%
df_xml_txt = df_xml.merge(df_txt, on='index')
df_xml_txt.head(2)
# Out:
#    index  time    age gender       pais          educacion  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
#
#                  ocupacion experiencia l_recomendado  \
# 0                    Other  5-10 years        Python
# 1  Program/Project Manager   20+ years        Python
#
#                                           plataforma        tpu  \
# 0                                           A laptop  2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#                     i_actual             e_tamanio e_analistas salario_actual  \
# 0  Manufacturing/Fabrication      50-249 employees         3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees         1-2  60,000-69,999
#
#   presupuesto_ml_cc big_products_used  \
# 0         $100-$999               NaN
# 1         $0 ($USD)               NaN
#
# ...

# %%
df_xml_txt_db = df_xml_txt.merge(df_db, on='index')
df_xml_txt_db.head(2)
# Out:
#    index  time    age gender       pais          educacion  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
#
#                  ocupacion experiencia l_recomendado  \
# 0                    Other  5-10 years        Python
# 1  Program/Project Manager   20+ years        Python
#
#                                           plataforma        tpu  \
# 0                                           A laptop  2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#                     i_actual             e_tamanio e_analistas salario_actual  \
# 0  Manufacturing/Fabrication      50-249 employees         3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees         1-2  60,000-69,999
#
#   presupuesto_ml_cc big_products_used  \
# 0         $100-$999               NaN
# 1         $0 ($USD)               NaN
#
# ...

# %%
df_xml_txt_db_csv = df_xml_txt_db.merge(df_csv, on='index')
df_xml_txt_db_csv.head(2)
# Out:
#    index  time    age gender       pais          educacion  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
#
#                  ocupacion experiencia l_recomendado  \
# 0                    Other  5-10 years        Python
# 1  Program/Project Manager   20+ years        Python
#
#                                           plataforma        tpu  \
# 0                                           A laptop  2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#                     i_actual             e_tamanio e_analistas salario_actual  \
# 0  Manufacturing/Fabrication      50-249 employees         3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees         1-2  60,000-69,999
#
#   presupuesto_ml_cc big_products_used  \
# 0         $100-$999               NaN
# 1         $0 ($USD)               NaN
#
# ...

# %%
#guardarlo en un archivo
df_xml_txt_db_csv.to_csv("data/05-data_union.csv")
