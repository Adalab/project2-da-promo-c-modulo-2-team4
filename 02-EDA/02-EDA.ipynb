# %% [markdown]
# # EDA

# %%
import pandas as pd
import re
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidetable

# %%
pd.options.display.max_columns = None

# %% [markdown]
# Cargamos el archivo limpio

# %%
df = pd.read_csv("../data/6.dataframe_analisis.csv", index_col = 0)
df.head(2)
# Out:
#       q1_edad q2_genero    q3_pais       q4_educacion  \
# index
# 0       50-54       Man      India  Bachelor’s degree
# 1       50-54       Man  Indonesia    Master’s degree
#
#                   q5_ocupacion q6_exp_tech q8_l_recomendado  \
# index
# 0                        Other  5-10 years           Python
# 1      Program/Project Manager   20+ years           Python
#
#                                      q11_tipo_plataforma  \
# index
# 0                                               A laptop
# 1      A cloud computing platform (AWS, Azure, GCP, h...
#
#                     q20_i_actual       q21_tamanio_cia q22_da_cia  \
# index
# 0      Manufacturing/Fabrication      50-249 employees        3-4
# 1      Manufacturing/Fabrication  1000-9,999 employees        1-2
#
#          q25_salario q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# index
# 0      25,000-29,999      $100-$999                 NaN              NaN
# 1      60,000-69,999      $0 ($USD)                 NaN              NaN
#
#                                       q41_h_process_data     q7_l_utilizados  \
# index
# 0      Local development environments (RStudio, Jupyt...           Python, R
# 1        Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                             q9_adi  \
# index
# 0                      Vim / Emacs
# 1       Notepad++,Jupyter Notebook
#
#                                                q14_h_viz         q10_part_1  \
# index
# 0       Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                            Matplotlib    Kaggle Notebooks
#
#             q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# index
# 0      Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1      Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#       q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# index
# 0            NaN        NaN         NaN         NaN         NaN         NaN
# 1            NaN        NaN         NaN         NaN         NaN         NaN
#
#       q10_part_14 q10_part_15 q10_part_16 q10_other  \
# index
# 0             NaN         NaN         NaN       NaN
# 1             NaN         NaN         NaN       NaN
#
#                                               q18_part_1 q18_part_2  \
# index
# 0      General purpose image/video tools (PIL, cv2, s...        NaN
# 1                                                    NaN        NaN
#
#       q18_part_3 q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1  \
# index
# 0            NaN        NaN        NaN        NaN       NaN          NaN
# 1            NaN        NaN        NaN        NaN       NaN          NaN
#
#       q27_a_part_2                   q27_a_part_3 q27_a_part_4 q27_a_part_5  \
# index
# 0              NaN   Google Cloud Platform (GCP)           NaN          NaN
# 1              NaN                            NaN          NaN          NaN
#
#       q27_a_part_6 q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10  \
# index
# 0              NaN          NaN          NaN          NaN           NaN
# 1              NaN          NaN          NaN          NaN           NaN
#
#       q27_a_part_11 q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4  \
# index
# 0               NaN         NaN        NaN        NaN        NaN    GitHub
# 1               NaN         NaN        NaN        NaN        NaN        NaN
#
#       q39_part_5 q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other  \
# index
# 0            NaN    Kaggle         NaN        NaN        NaN       NaN
# 1            NaN        NaN        NaN        NaN        NaN       NaN
#
#       q40_part_1 q40_part_2            q40_part_3 q40_part_4 q40_part_5  \
# index
# 0       Coursera        edX  Kaggle Learn Courses   DataCamp        NaN
# 1            NaN        NaN  Kaggle Learn Courses        NaN        NaN
#
#       q40_part_6 q40_part_7 q40_part_8  \
# index
# 0        Udacity      Udemy        NaN
# 1            NaN        NaN        NaN
#
#                                               q40_part_9  \
# index
# 0                                                    NaN
# 1      Cloud-certification programs (direct from AWS,...
#
#                                              q40_part_10 q40_part_11  \
# index
# 0                                                    NaN         NaN
# 1      University Courses (resulting in a university ...         NaN
#
#       q40_other q42_part_1                                         q42_part_2  \
# index
# 0           NaN        NaN  Email newsletters (Data Elixir, O'Reilly Data ...
# 1           NaN        NaN                                                NaN
#
#       q42_part_3                       q42_part_4 q42_part_5  \
# index
# 0            NaN  Kaggle (notebooks, forums, etc)        NaN
# 1            NaN                              NaN        NaN
#
#                                               q42_part_6  \
# index
# 0      YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                    NaN
#
#                                               q42_part_7  \
# index
# 0      Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                    NaN
#
#                                               q42_part_8  \
# index
# 0      Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                    NaN
#
#                                               q42_part_9 q42_part_10  \
# index
# 0      Journal Publications (peer-reviewed journals, ...         NaN
# 1      Journal Publications (peer-reviewed journals, ...         NaN
#
#       q42_part_11 q42_other
# index
# 0             NaN       NaN
# 1             NaN       NaN

# %% [markdown]
# #  Exploración de los nulos

# %%
df.shape
# Out:
# (25973, 89)

# %%
df_nulos = pd.DataFrame(df.isnull().sum()*100/df.shape[0])
df_nulos
# Out:
#                       0
# q1_edad        0.000000
# q2_genero      0.000000
# q3_pais        0.000000
# q4_educacion   0.000000
# q5_ocupacion   0.000000
# ...                 ...
# q42_part_8    69.287337
# q42_part_9    87.101991
# q42_part_10   92.318947
# q42_part_11   96.122897
# q42_other     97.755361
#
# [89 rows x 1 columns]

# %%
df.stb.missing()[50:70]
# Out:
#                      missing  total    percent
# q40_part_2             22945  25973  88.341739
# q39_part_6             22908  25973  88.199284
# q27_a_part_3           22831  25973  87.902822
# q39_part_9             22806  25973  87.806568
# q42_part_9             22623  25973  87.101991
# q42_part_2             22532  25973  86.751627
# q27_a_part_1           22252  25973  85.673584
# q42_part_1             22226  25973  85.573480
# q40_part_4             21977  25973  84.614792
# q18_part_4             21600  25973  83.163285
# q39_part_4             21387  25973  82.343203
# q33_bigdata_product    21317  25973  82.073692
# q40_part_10            21091  25973  81.203558
# q40_part_7             19533  25973  75.205021
# q10_part_16            18799  25973  72.379009
# q42_part_8             17996  25973  69.287337
# q40_part_3             17303  25973  66.619181
# q10_part_1             16466  25973  63.396604
# q40_part_1             16324  25973  62.849883
# q10_part_2             16181  25973  62.299311

# %%
df.dtypes
# Out:
# q1_edad         object
# q2_genero       object
# q3_pais         object
# q4_educacion    object
# q5_ocupacion    object
#                  ...
# q42_part_8      object
# q42_part_9      object
# q42_part_10     object
# q42_part_11     object
# q42_other       object
# Length: 89, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25973 entries, 0 to 25972
# Data columns (total 89 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   q1_edad              25973 non-null  object
#  1   q2_genero            25973 non-null  object
#  2   q3_pais              25973 non-null  object
#  3   q4_educacion         25973 non-null  object
#  4   q5_ocupacion         25973 non-null  object
#  5   q6_exp_tech          25973 non-null  object
#  6   q8_l_recomendado     24940 non-null  object
#  7   q11_tipo_plataforma  24720 non-null  object
#  8   q20_i_actual         16325 non-null  object
#  9   q21_tamanio_cia      16251 non-null  object
#  10  q22_da_cia           16126 non-null  object
#  11  q25_salario          15391 non-null  object
#  12  q26_ppto_ml_cc       15183 non-null  object
#  13  q33_bigdata_product  4656 non-null   object
#  14  q35_h_i_negocios     2237 non-null   object
#  15  q41_h_process_data   18489 non-null  object
#  16  q7_l_utilizados      24941 non-null  object
#  17  q9_adi               24934 non-null  object
#  18  q14_h_viz            23970 non-null  object
#  19  q10_part_1           9507 non-null   object
#  20  q10_part_2           9792 non-null   object
#  21  q10_part_3           1062 non-null   object
#  22  q10_part_4           209 non-null    object
#  23  q10_part_5           1770 non-null   object
#  24  q10_part_6           175 non-null    object
#  25  q10_part_7           1067 non-null   object
#  26  q10_part_8           753 non-null    object
#  27  q10_part_9           348 non-null    object
#  28  q10_part_10          2051 non-null   object
#  29  q10_part_11          1794 non-null   object
#  30  q10_part_12          590 non-null    object
#  31  q10_part_13          251 non-null    object
#  32  q10_part_14          260 non-null    object
#  33  q10_part_15          147 non-null    object
#  34  q10_part_16          7174 non-null   object
#  35  q10_other            737 non-null    object
#  36  q18_part_1           2662 non-null   object
#  37  q18_part_2           2740 non-null   object
#  38  q18_part_3           2716 non-null   object
#  39  q18_part_4           4373 non-null   object
#  40  q18_part_5           1492 non-null   object
#  41  q18_part_6           1439 non-null   object
#  42  q18_other            119 non-null    object
#  43  q27_a_part_1         3721 non-null   object
#  44  q27_a_part_2         2450 non-null   object
#  45  q27_a_part_3         3142 non-null   object
#  46  q27_a_part_4         572 non-null    object
#  47  q27_a_part_5         454 non-null    object
#  48  q27_a_part_6         290 non-null    object
#  49  q27_a_part_7         275 non-null    object
#  50  q27_a_part_8         390 non-null    object
#  51  q27_a_part_9         259 non-null    object
#  52  q27_a_part_10        172 non-null    object
#  53  q27_a_part_11        2689 non-null   object
#  54  q27_a_other          337 non-null    object
#  55  q39_part_1           293 non-null    object
#  56  q39_part_2           387 non-null    object
#  57  q39_part_3           136 non-null    object
#  58  q39_part_4           4586 non-null   object
#  59  q39_part_5           705 non-null    object
#  60  q39_part_6           3065 non-null   object
#  61  q39_part_7           1848 non-null   object
#  62  q39_part_8           305 non-null    object
#  63  q39_part_9           3167 non-null   object
#  64  q39_other            306 non-null    object
#  65  q40_part_1           9649 non-null   object
#  66  q40_part_2           3028 non-null   object
#  67  q40_part_3           8670 non-null   object
#  68  q40_part_4           3996 non-null   object
#  69  q40_part_5           1157 non-null   object
#  70  q40_part_6           2803 non-null   object
#  71  q40_part_7           6440 non-null   object
#  72  q40_part_8           2693 non-null   object
#  73  q40_part_9           1804 non-null   object
#  74  q40_part_10          4882 non-null   object
#  75  q40_part_11          1762 non-null   object
#  76  q40_other            2081 non-null   object
#  77  q42_part_1           3747 non-null   object
#  78  q42_part_2           3441 non-null   object
#  79  q42_part_3           2939 non-null   object
#  80  q42_part_4           11373 non-null  object
#  81  q42_part_5           2996 non-null   object
#  82  q42_part_6           10401 non-null  object
#  83  q42_part_7           2022 non-null   object
#  84  q42_part_8           7977 non-null   object
#  85  q42_part_9           3350 non-null   object
#  86  q42_part_10          1995 non-null   object
#  87  q42_part_11          1007 non-null   object
#  88  q42_other            583 non-null    object
# dtypes: object(89)
# memory usage: 17.8+ MB

# %% [markdown]
# # Variables categoricas

# %%
df_categoricas = df.select_dtypes(include = "object")
df_categoricas.head(2)
# Out:
#       q1_edad q2_genero    q3_pais       q4_educacion  \
# index
# 0       50-54       Man      India  Bachelor’s degree
# 1       50-54       Man  Indonesia    Master’s degree
#
#                   q5_ocupacion q6_exp_tech q8_l_recomendado  \
# index
# 0                        Other  5-10 years           Python
# 1      Program/Project Manager   20+ years           Python
#
#                                      q11_tipo_plataforma  \
# index
# 0                                               A laptop
# 1      A cloud computing platform (AWS, Azure, GCP, h...
#
#                     q20_i_actual       q21_tamanio_cia q22_da_cia  \
# index
# 0      Manufacturing/Fabrication      50-249 employees        3-4
# 1      Manufacturing/Fabrication  1000-9,999 employees        1-2
#
#          q25_salario q26_ppto_ml_cc q33_bigdata_product q35_h_i_negocios  \
# index
# 0      25,000-29,999      $100-$999                 NaN              NaN
# 1      60,000-69,999      $0 ($USD)                 NaN              NaN
#
#                                       q41_h_process_data     q7_l_utilizados  \
# index
# 0      Local development environments (RStudio, Jupyt...           Python, R
# 1        Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                             q9_adi  \
# index
# 0                      Vim / Emacs
# 1       Notepad++,Jupyter Notebook
#
#                                                q14_h_viz         q10_part_1  \
# index
# 0       Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...                NaN
# 1                                            Matplotlib    Kaggle Notebooks
#
#             q10_part_2 q10_part_3 q10_part_4 q10_part_5 q10_part_6 q10_part_7  \
# index
# 0      Colab Notebooks        NaN        NaN        NaN        NaN        NaN
# 1      Colab Notebooks        NaN        NaN        NaN        NaN        NaN
#
#       q10_part_8 q10_part_9 q10_part_10 q10_part_11 q10_part_12 q10_part_13  \
# index
# 0            NaN        NaN         NaN         NaN         NaN         NaN
# 1            NaN        NaN         NaN         NaN         NaN         NaN
#
#       q10_part_14 q10_part_15 q10_part_16 q10_other  \
# index
# 0             NaN         NaN         NaN       NaN
# 1             NaN         NaN         NaN       NaN
#
#                                               q18_part_1 q18_part_2  \
# index
# 0      General purpose image/video tools (PIL, cv2, s...        NaN
# 1                                                    NaN        NaN
#
#       q18_part_3 q18_part_4 q18_part_5 q18_part_6 q18_other q27_a_part_1  \
# index
# 0            NaN        NaN        NaN        NaN       NaN          NaN
# 1            NaN        NaN        NaN        NaN       NaN          NaN
#
#       q27_a_part_2                   q27_a_part_3 q27_a_part_4 q27_a_part_5  \
# index
# 0              NaN   Google Cloud Platform (GCP)           NaN          NaN
# 1              NaN                            NaN          NaN          NaN
#
#       q27_a_part_6 q27_a_part_7 q27_a_part_8 q27_a_part_9 q27_a_part_10  \
# index
# 0              NaN          NaN          NaN          NaN           NaN
# 1              NaN          NaN          NaN          NaN           NaN
#
#       q27_a_part_11 q27_a_other q39_part_1 q39_part_2 q39_part_3 q39_part_4  \
# index
# 0               NaN         NaN        NaN        NaN        NaN    GitHub
# 1               NaN         NaN        NaN        NaN        NaN        NaN
#
#       q39_part_5 q39_part_6 q39_part_7 q39_part_8 q39_part_9 q39_other  \
# index
# 0            NaN    Kaggle         NaN        NaN        NaN       NaN
# 1            NaN        NaN        NaN        NaN        NaN       NaN
#
#       q40_part_1 q40_part_2            q40_part_3 q40_part_4 q40_part_5  \
# index
# 0       Coursera        edX  Kaggle Learn Courses   DataCamp        NaN
# 1            NaN        NaN  Kaggle Learn Courses        NaN        NaN
#
#       q40_part_6 q40_part_7 q40_part_8  \
# index
# 0        Udacity      Udemy        NaN
# 1            NaN        NaN        NaN
#
#                                               q40_part_9  \
# index
# 0                                                    NaN
# 1      Cloud-certification programs (direct from AWS,...
#
#                                              q40_part_10 q40_part_11  \
# index
# 0                                                    NaN         NaN
# 1      University Courses (resulting in a university ...         NaN
#
#       q40_other q42_part_1                                         q42_part_2  \
# index
# 0           NaN        NaN  Email newsletters (Data Elixir, O'Reilly Data ...
# 1           NaN        NaN                                                NaN
#
#       q42_part_3                       q42_part_4 q42_part_5  \
# index
# 0            NaN  Kaggle (notebooks, forums, etc)        NaN
# 1            NaN                              NaN        NaN
#
#                                               q42_part_6  \
# index
# 0      YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                    NaN
#
#                                               q42_part_7  \
# index
# 0      Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                    NaN
#
#                                               q42_part_8  \
# index
# 0      Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                    NaN
#
#                                               q42_part_9 q42_part_10  \
# index
# 0      Journal Publications (peer-reviewed journals, ...         NaN
# 1      Journal Publications (peer-reviewed journals, ...         NaN
#
#       q42_part_11 q42_other
# index
# 0             NaN       NaN
# 1             NaN       NaN

# %% [markdown]
# # Variables numericas

# %%
df_numericas = df.select_dtypes(include=np.number)
df_numericas.head(2)

# No existen variables numéricas
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %% [markdown]
# # Principales estadisticos del dafaframe

# %%
# df_numericas.describe().T

# %%
df_categoricas.describe(include="object").T
# Out:
#               count unique                                                top  \
# q1_edad       25973     11                                              25-29
# q2_genero     25973      5                                                Man
# q3_pais       25973     66                                              India
# q4_educacion  25973      7                                    Master’s degree
# q5_ocupacion  25973     15                                            Student
# ...             ...    ...                                                ...
# q42_part_8     7977      1  Blogs (Towards Data Science, Analytics Vidhya,...
# q42_part_9     3350      1  Journal Publications (peer-reviewed journals, ...
# q42_part_10    1995      1       Slack Communities (ods.ai, kagglenoobs, etc)
# q42_part_11    1007      1                                               None
# q42_other       583      1                                              Other
#
#                freq
# q1_edad        4931
# q2_genero     20598
# q3_pais        7434
# q4_educacion  10132
# q5_ocupacion   6804
# ...             ...
# q42_part_8     7977
# q42_part_9     3350
# q42_part_10    1995
# q42_part_11    1007
# q42_other       583
#
# [89 rows x 4 columns]

# %% [markdown]
# # Valores unicos y su frecuencia en un DF

# %%
# Creamos un Dataframe a partir de un diccionario.
# Creamos dos listas para meter el nombre de la variable y los valores unicos
variable = []
n_uniques = []
for col in df_categoricas.columns: # Iteramos por las columnas de DF categoricas y apendeamos los distintos valores
    variable.append(col)
    n_uniques.append(df_categoricas[col].unique())
datos = {"variable": variable, "n_uniques": n_uniques} # Creamos el diccionario

# %%
# Creamos el Dataframe a partir del diccionario
df_valoresunicos = pd.DataFrame.from_dict(datos)

# %%
df_valoresunicos
# Out:
#         variable                                          n_uniques
# 0        q1_edad  [50-54, 22-24, 45-49, 25-29, 18-21, 30-34, 40-...
# 1      q2_genero  [Man, Woman, Nonbinary, Prefer not to say, Pre...
# 2        q3_pais  [India, Indonesia, Pakistan, Mexico, Russia, T...
# 3   q4_educacion  [Bachelor’s degree, Master’s degree, Doctoral ...
# 4   q5_ocupacion  [Other, Program/Project Manager, Software Engi...
# ..           ...                                                ...
# 84    q42_part_8  [Blogs (Towards Data Science, Analytics Vidhya...
# 85    q42_part_9  [Journal Publications (peer-reviewed journals,...
# 86   q42_part_10  [nan, Slack Communities (ods.ai, kagglenoobs, ...
# 87   q42_part_11                                        [nan, None]
# 88     q42_other                                       [nan, Other]
#
# [89 rows x 2 columns]

# %% [markdown]
# # Frecuencia en las columnas

# %%
df.columns
# Out:
# Index(['q1_edad', 'q2_genero', 'q3_pais', 'q4_educacion', 'q5_ocupacion',
#        'q6_exp_tech', 'q8_l_recomendado', 'q11_tipo_plataforma',
#        'q20_i_actual', 'q21_tamanio_cia', 'q22_da_cia', 'q25_salario',
#        'q26_ppto_ml_cc', 'q33_bigdata_product', 'q35_h_i_negocios',
#        'q41_h_process_data', 'q7_l_utilizados', 'q9_adi', 'q14_h_viz',
#        'q10_part_1', 'q10_part_2', 'q10_part_3', 'q10_part_4', 'q10_part_5',
#        'q10_part_6', 'q10_part_7', 'q10_part_8', 'q10_part_9', 'q10_part_10',
#        'q10_part_11', 'q10_part_12', 'q10_part_13', 'q10_part_14',
#        'q10_part_15', 'q10_part_16', 'q10_other', 'q18_part_1', 'q18_part_2',
#        'q18_part_3', 'q18_part_4', 'q18_part_5', 'q18_part_6', 'q18_other',
#        'q27_a_part_1', 'q27_a_part_2', 'q27_a_part_3', 'q27_a_part_4',
#        'q27_a_part_5', 'q27_a_part_6', 'q27_a_part_7', 'q27_a_part_8',
#        'q27_a_part_9', 'q27_a_part_10', 'q27_a_part_11', 'q27_a_other',
#        'q39_part_1', 'q39_part_2', 'q39_part_3', 'q39_part_4', 'q39_part_5',
#        'q39_part_6', 'q39_part_7', 'q39_part_8', 'q39_part_9', 'q39_other',
#        'q40_part_1', 'q40_part_2', 'q40_part_3', 'q40_part_4', 'q40_part_5',
#        'q40_part_6', 'q40_part_7', 'q40_part_8', 'q40_part_9', 'q40_part_10',
#        'q40_part_11', 'q40_other', 'q42_part_1', 'q42_part_2', 'q42_part_3',
#        'q42_part_4', 'q42_part_5', 'q42_part_6', 'q42_part_7', 'q42_part_8',
#        'q42_part_9', 'q42_part_10', 'q42_part_11', 'q42_other'],
#       dtype='object')

# %%
df.stb.freq(['q1_edad'], thresh=80)
# Out:
#   q1_edad  count    percent  cumulative_count  cumulative_percent
# 0   25-29   4931  18.985100              4931           18.985100
# 1   18-21   4901  18.869595              9832           37.854695
# 2   22-24   4694  18.072614             14526           55.927309
# 3   30-34   3441  13.248373             17967           69.175682
# 4   35-39   2504   9.640781             20471           78.816463
# 5  others   5502  21.183537             25973          100.000000

# %% [markdown]
# # Outliers

# %% [markdown]
# Todas las variables categóricas

# %% [markdown]
# Boxplot

# %%
# fig, ax = plt.subplots(7, 1, figsize=(15,35))

# for i, column in enumerate(df_numericas):
    # sns.boxplot(x=df_numericas[column], data=df_numericas, ax=ax[i])
# plt.show()

# %% [markdown]
# Desviación estandar

# %%
# No aplica

# %% [markdown]
#  # Relaciones entre variables  NUMERICAS

# %% [markdown]
# heatmap

# %% [markdown]
# Scatterplot

# %% [markdown]
#  # Relaciones entre variables CATÉGORICAS

# %% [markdown]
# Countplot

# %%
categoricas = list(df_categoricas.columns[0:5])
categoricas
# Out:
# ['q1_edad', 'q2_genero', 'q3_pais', 'q4_educacion', 'q5_ocupacion']

# %%
df_edades = df_categoricas["q1_edad"].value_counts()
df_edades
# Out:
# 25-29    4931
# 18-21    4901
# 22-24    4694
# 30-34    3441
# 35-39    2504
# 40-44    1890
# 45-49    1375
# 50-54     964
# 55-59     592
# 60-69     553
# 70+       128
# Name: q1_edad, dtype: int64

# %%
#for i in df_edades.columns:
    #df[i].value_counts()
   #print (df_edades[i].value_counts())

# %%
def dicc_categoricas(lista_columnas, dataframe): 
    
    dicc_cat = {} # creamos un diccionario donde almacenaremos índices de los outliers
             
    for i in df_categoricas.columns:
        dicc_cat.setdefault(df_categoricas.i.value_counts())
                  
    return dicc_cat

# %%
#detectar_outliers(categoricas, df_categoricas)

# %% [markdown]
#  # Relaciones entre variables CATÉGORICAS y NÚMERICAS

# %% [markdown]
# boxplot con el rango intercuartilico

# %% [markdown]
# # Countplot

# %% [markdown]
# - País
# - Salario

# %%
def graficar_countplot (df,lista):

    df_lista = df[lista]

    fig, axes = plt.subplots(1, len(lista), figsize=(25,6))

    for ax in fig.axes:
        ax.tick_params(labelrotation=90)

    for i in range(len(df_lista.columns)):
        sns.countplot(x = df_lista.columns[i], data = df, ax=axes[i]); 
    
    return plt.show();

# %%
graficar_countplot (df_categoricas,categoricas)

# %%
# Pendiente de hacer
def countrplot_columna (df,lista):
    df_lista = df[lista]

    fig, axes = plt.subplots(1, len(lista), figsize=(25,6))

    for ax in fig.axes:
        ax.tick_params(labelrotation=90)

    for i in range(len(df_lista.columns)):
        sns.countplot(x = df_lista.columns[i], data = df, ax=axes[i]); 
    return   plt.show();

# %%
categoricas = list(df_categoricas.columns[0:4])
categoricas
# Out:
# ['q1_edad', 'q2_genero', 'q3_pais', 'q4_educacion']

# %%
categoricas2 = list(df_categoricas.columns[5:9])
categoricas2
# Out:
# ['q6_exp_tech', 'q8_l_recomendado', 'q11_tipo_plataforma', 'q20_i_actual']

# %%
categoricas3 = list(df_categoricas.columns[10:15])
categoricas3
# Out:
# ['q22_da_cia',
#  'q25_salario',
#  'q26_ppto_ml_cc',
#  'q33_bigdata_product',
#  'q35_h_i_negocios']

# %%
countrplot_columna (df_categoricas,categoricas)

# %%
countrplot_columna (df_categoricas,categoricas2)

# %%
countrplot_columna (df_categoricas,categoricas3)
